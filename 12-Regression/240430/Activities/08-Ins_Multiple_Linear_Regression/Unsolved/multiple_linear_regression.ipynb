# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Import the data
car_data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m12/lesson_1/datasets/car-data-encoded.csv")
car_data
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                NaN     0          1           0           2.0
# 1            3                NaN     0          1           0           2.0
# 2            1                NaN     0          1           0           2.0
# 3            2              164.0     1          1           0           4.0
# 4            2              164.0     1          1           0           4.0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0    21          1           0           4.0
# 201         -1               95.0    21          1           1           4.0
# 202         -1               95.0    21          1           0           4.0
# 203         -1               95.0    21          0           1           4.0
# 204         -1               95.0    21          1           1           4.0
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0             0             2                0        88.6  ...          130
# 1             0             2                0        88.6  ...          130
# 2             2             2                0        94.5  ...          152
# 3             3             1                0        99.8  ...          109
# 4             3             0                0        99.4  ...          136
# ..          ...           ...              ...         ...  ...          ...
# 200           3             2                0       109.1  ...          141
# 201           3             2                0       109.1  ...          141
# 202           3             2                0       109.1  ...          173
# 203           3             2                0       109.1  ...          145
# 204           3             2                0       109.1  ...          141
#
#      fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0              5  3.47    2.68                9.0       111.0    5000.0
# 1              5  3.47    2.68                9.0       111.0    5000.0
# 2              5  2.68    3.47                9.0       154.0    5000.0
# 3              5  3.19    3.40               10.0       102.0    5500.0
# 4              5  3.19    3.40                8.0       115.0    5500.0
# ..           ...   ...     ...                ...         ...       ...
# 200            5  3.78    3.15                9.5       114.0    5400.0
# 201            5  3.78    3.15                8.7       160.0    5300.0
# 202            5  3.58    2.87                8.8       134.0    5500.0
# 203            3  3.01    3.40               23.0       106.0    4800.0
# 204            5  3.78    3.15                9.5       114.0    5400.0
#
#      city-mpg  highway-mpg    price
# 0          21           27  13495.0
# 1          21           27  16500.0
# 2          19           26  16500.0
# 3          24           30  13950.0
# 4          18           22  17450.0
# ..        ...          ...      ...
# 200        23           28  16845.0
# 201        19           25  19045.0
# 202        18           23  21485.0
# 203        26           27  22470.0
# 204        19           25  22625.0
#
# [205 rows x 26 columns]

# %%
# Drop na rows
car_data = car_data.dropna()

# %% [markdown]
# ## Split into training and testing sets

# %%
# Features to include: "make", "fuel-type", "num-of-doors", "drive-wheels",
# "length", "width", "height", "engine-size", "fuel-system", "city-mpg"
features = ["make", "fuel-type", "num-of-doors", "drive-wheels", 
            "length", "width", "height", "engine-size", 
            "fuel-system", "city-mpg"]
X = car_data[features]
X.head()
# Out:
#     make  fuel-type  num-of-doors  drive-wheels  length  width  height  \
# 3      1          1           4.0             1   176.6   66.2    54.3
# 4      1          1           4.0             0   176.6   66.4    54.3
# 6      1          1           4.0             1   192.7   71.4    55.7
# 8      1          1           4.0             1   192.7   71.4    55.9
# 10     2          1           2.0             2   176.8   64.8    54.3
#
#     engine-size  fuel-system  city-mpg
# 3           109            5        24
# 4           136            5        18
# 6           136            5        19
# 8           131            5        17
# 10          108            5        23

# %%
# Set the target variable y
y = car_data["price"]

# %%
# Now split the data into training and testing sets again
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## Train the model

# %%
# Create the model
model = LinearRegression()

# Fit the model to the training data. 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Evaluate the model

# %%
mean_squared_error, r2_score

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
predicted = model.predict(X_test)


# Use our model to make predictions
mse = mean_squared_error(y_test, predicted)
r2  = r2_score(y_test, predicted)


# Score the predictions with mse and r2
print(f"mean squared error (MSE):{mse}")
print(f"R-Squared (R2):{r2}")
# Out:
# mean squared error (MSE):6997124.5179336
# R-Squared (R2):0.7328093736318091

# %%
# Call the `score()` method on the model to show the R2 score
model.score(X_test, y_test)
# Out:
# 0.7328093736318091

# %%
list(zip(X.columns, model.coef_))
# Out:
# [('make', -145.6381423054333),
#  ('fuel-type', -2100.0381208386875),
#  ('num-of-doors', 151.49079291595268),
#  ('drive-wheels', 1636.4660095422923),
#  ('length', -52.47452453119088),
#  ('width', 1181.049385535658),
#  ('height', 149.1822992482001),
#  ('engine-size', 77.04145717460356),
#  ('fuel-system', 229.48468116293319),
#  ('city-mpg', -130.62144259276556)]

# %%
model.intercept_
y = -70077.1721723608 + -145.63X_i_1 + -2100.03X_i_2 ... X_i_10
# Out:
# -70077.1721723608
