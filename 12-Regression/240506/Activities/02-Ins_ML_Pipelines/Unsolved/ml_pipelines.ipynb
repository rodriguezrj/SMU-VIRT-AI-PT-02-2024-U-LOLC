# %%
import pandas as pd

# Import the data
rent_tx_df = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m12/lesson_3/datasets/rent_data_tx.csv")
rent_ca_df = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m12/lesson_3/datasets/rent_data_ca.csv")

# %%
# Look at the first few rows of the california data
rent_ca_df.head()
# Out:
#            id                category  \
# 0  5668627426  housing/rent/apartment
# 1  5668610290  housing/rent/apartment
# 2  5664571820  housing/rent/apartment
# 3  5668633573  housing/rent/apartment
# 4  5668624017  housing/rent/apartment
#
#                                                title  \
# 0                   Studio apartment 2432 Penmar Ave
# 1                       Studio apartment 333 Hyde St
# 2                  Studio apartment 57 Taylor Street
# 3  Studio apartment 545 Georgia street 717-723 Su...
# 4                              One BR Arballo Dr 12d
#
#                                                 body     amenities  bathrooms  \
# 0  This unit is located at 2432 Penmar Ave, Venic...           NaN        NaN
# 1  This unit is located at 333 Hyde St, San Franc...  Refrigerator        1.0
# 2  This unit is located at 57 Taylor Street, San ...  Refrigerator        1.0
# 3  This unit is located at 545 Georgia street 717...           NaN        1.0
# 4  This unit is located at Arballo Dr 12d, San Fr...           NaN        1.0
#
#    bedrooms currency fee  has_photo  ... price_display  price_type  \
# 0       0.0      USD  No  Thumbnail  ...        $1,800     Monthly
# 1       0.0      USD  No  Thumbnail  ...        $1,495     Monthly
# 2       0.0      USD  No  Thumbnail  ...        $1,695     Monthly
# 3       1.0      USD  No  Thumbnail  ...          $950     Monthly
# 4       1.0      USD  No  Thumbnail  ...        $1,400     Monthly
#
#   square_feet                           address       cityname state latitude  \
# 0         132                2432 Penmar Avenue         Venice    CA  33.9932
# 1         138                       333 Hyde St  San Francisco    CA  37.7599
# 2         190                      57 Taylor St  San Francisco    CA  37.7599
# 3         200  545 Georgia St 717-723 Sutter St        Vallejo    CA  38.1172
# 4         219                               NaN  San Francisco    CA  37.7599
#
#   longitude     source        time
# 0 -118.4609  RentLingo  1577359461
# 1 -122.4379  RentLingo  1577358313
# 2 -122.4379  RentLingo  1577015121
# 3 -122.2313  RentLingo  1577359918
# 4 -122.4379  RentLingo  1577359209
#
# [5 rows x 22 columns]

# %%
# Import the pipeline_utilities module
import pipeline_utilities as utils

# %%
# Train a model for Texas using the rent_model_generator function
utils.rent_model_generator(rent_tx_df)
# Out:
# Dropped 73.58% rows
# Testing dropped NAs
# Mean Squared Error: 83039.02871487192
# R-squared: 0.4297900037709652
# Adjusted R-squared: 0.30103290784827996
#
# Testing no dropped data
# Mean Squared Error: 106755.71107931268
# R-squared: 0.33231879100000183
# Adjusted R-squared: 0.29836889901695096
#
# Pipeline dropping null values
# Pipeline(steps=[('One hot encode', OneHotEncoder(handle_unknown='ignore')),
#                 ('Scale', StandardScaler(with_mean=False)),
#                 ('Linear Regression', LinearRegression())])

# %%
# Train a model for California using the rent_model_generator function
utils.rent_model_generator(rent_ca_df)
# Out:
# Dropped 82.51% rows
# Testing dropped NAs
# Mean Squared Error: 1024812.520392654
# R-squared: 0.052313962749153786
# Adjusted R-squared: -0.9427563763642346
#
# Testing no dropped data
# Mean Squared Error: 11349100.80185271
# R-squared: 0.05072758060489202
# Adjusted R-squared: -0.04113749223979579
#
# Pipeline with all data
# Pipeline(steps=[('One hot encode', OneHotEncoder(handle_unknown='ignore')),
#                 ('Scale', StandardScaler(with_mean=False)),
#                 ('Linear Regression', LinearRegression())])
