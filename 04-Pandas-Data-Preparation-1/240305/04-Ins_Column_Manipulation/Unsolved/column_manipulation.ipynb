# %%
# Import Dependencies
import pandas as pd

# %%
# A DataFrame of individuals' contact information
PATH_VARIABLE = '../Resources/people.csv'

people_df = pd.read_csv(PATH_VARIABLE)
people_df.head()
# Out:
#   first_name last_name gender  age           company_name  \
# 0       Rufe  Eickhoff      M   54         Zieme and Sons
# 1     Berkie    Morson      M   20        Gibson and Sons
# 2     Urbano     Polly      M   29         Brown-Dietrich
# 3   Alphonso   Bourley      M   29          Hansen-Russel
# 4     Munmro     Fenck      M   57  Jaskolski and D'Amore
#
#                  address           city        phone1        phone2  \
# 0    0 Summer Ridge Pass         Mizque  740-948-0089  177-453-4212
# 1  37963 Linden Crossing    Ouro Branco  168-714-9518  435-628-4078
# 2      772 Crowley Court          Banff  126-409-5968  523-115-7431
# 3     0 Graceland Avenue  Sabana Grande  583-906-8550  363-721-4939
# 4          7 Rowland Way          Pitai  141-960-7812  652-495-4816
#
#                     email
# 0      reickhoff0@last.fm
# 1  bmorson1@homestead.com
# 2      upolly2@cdbaby.com
# 3     abourley3@issuu.com
# 4   mfenck4@mediafire.com

# %%
people_df
# Out:
#           first_name last_name gender  age                  company_name  \
# 0               Rufe  Eickhoff      M   54                Zieme and Sons
# 1             Berkie    Morson      M   20               Gibson and Sons
# 2             Urbano     Polly      M   29                Brown-Dietrich
# 3           Alphonso   Bourley      M   29                 Hansen-Russel
# 4             Munmro     Fenck      M   57         Jaskolski and D'Amore
# ..               ...       ...    ...  ...                           ...
# 495          Perrine    Patria      F   79  Heaney, Marks and Williamson
# 496             Perl   Parrett      F   38                  Schuppe-Wiza
# 497            Eleen   Jakeman      F   37                Lakin and Sons
# 498           Crysta   Barfoot      F   60       Graham, Koss and Larkin
# 499  Helen-elizabeth     McKew      F   40   Wisozk, Mueller and Streich
#
#                     address            city        phone1        phone2  \
# ...

# %%
print(people_df.shape)
print(len(people_df))
# Out:
# (500, 10)
# 500

# %%
# Collect a list of all columns within the DataFrame
people_df.columns
# Out:
# Index(['first_name', 'last_name', 'gender', 'age', 'company_name', 'address',
#        'city', 'phone1', 'phone2', 'email'],
#       dtype='object')

# %%
# Reorganize the columns using double brackets
organized_df = people_df[['first_name', 'last_name', 'email', 'gender', 'age', 'company_name', 'address', 
                          'city']]
organized_df.head()
# Out:
#   first_name last_name                   email gender  age  \
# 0       Rufe  Eickhoff      reickhoff0@last.fm      M   54
# 1     Berkie    Morson  bmorson1@homestead.com      M   20
# 2     Urbano     Polly      upolly2@cdbaby.com      M   29
# 3   Alphonso   Bourley     abourley3@issuu.com      M   29
# 4     Munmro     Fenck   mfenck4@mediafire.com      M   57
#
#             company_name                address           city
# 0         Zieme and Sons    0 Summer Ridge Pass         Mizque
# 1        Gibson and Sons  37963 Linden Crossing    Ouro Branco
# 2         Brown-Dietrich      772 Crowley Court          Banff
# 3          Hansen-Russel     0 Graceland Avenue  Sabana Grande
# 4  Jaskolski and D'Amore          7 Rowland Way          Pitai

# %%
# print(organized_df)

# %%
# Use .rename(columns={}) to rename columns
renamed_df = organized_df.rename(columns = {"first_name" : "First Name"})

# %%
renamed_df
# Out:
#           First Name last_name                      email gender  age  \
# 0               Rufe  Eickhoff         reickhoff0@last.fm      M   54
# 1             Berkie    Morson     bmorson1@homestead.com      M   20
# 2             Urbano     Polly         upolly2@cdbaby.com      M   29
# 3           Alphonso   Bourley        abourley3@issuu.com      M   29
# 4             Munmro     Fenck      mfenck4@mediafire.com      M   57
# ..               ...       ...                        ...    ...  ...
# 495          Perrine    Patria  ppatriadr@stumbleupon.com      F   79
# 496             Perl   Parrett       pparrettds@cam.ac.uk      F   38
# 497            Eleen   Jakeman       ejakemandt@prlog.org      F   37
# 498           Crysta   Barfoot        cbarfootdu@about.me      F   60
# 499  Helen-elizabeth     McKew           hmckewdv@ibm.com      F   40
#
#                      company_name                 address            city
# ...
