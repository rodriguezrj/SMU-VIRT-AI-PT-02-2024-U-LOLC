# %%
# Dependencies
import json
import requests
import pandas as pd

# %%
# Open library results limit to 50 results per page. 
# Authors documentation: https://openlibrary.org/dev/docs/api/authors
# URL for Neil Gaiman
url = "https://openlibrary.org/authors/OL53305A/works.json"

# %%
# Create an empty list to store the responses
response_json = []

# %%
# Make a request for 3 pages of results
for x in range(3):

    # Get the results
    post_response = requests.get(url + "?offset=" + str(x*50)).json()

    # Loop through the "entries" of the results and
    # append them to the response_json list
    for result in post_response['entries']:

        # Save post's JSON
        response_json.append(result)

# %%
# response_json
# Out:
# [{'description': 'American Gods (2001) is a fantasy novel by British author Neil Gaiman. The novel is a blend of Americana, fantasy, and various strands of ancient and modern mythology, all centering on the mysterious and taciturn Shadow.',
#   'links': [{'title': "Neil Gaiman | Neil's Work | Books | American Gods",
#     'url': 'http://www.neilgaiman.com/works/Books/American+Gods/ed/102/',
#     'type': {'key': '/type/link'}},
#    {'title': 'American Gods - Wikipedia',
#     'url': 'https://en.wikipedia.org/wiki/American_Gods',
#     'type': {'key': '/type/link'}},
#    {'title': 'publishersweekly.com/978-0-380-97365-1',
#     'url': 'https://www.publishersweekly.com/978-0-380-97365-1',
#     'type': {'key': '/type/link'}},
#    {'title': 'Neil Gaiman, “American Gods: The Tenth Anniversary Edition”',
#     'url': 'https://www.newyorker.com/recommends/listen/american-gods-the-tenth-anniversary-edition',
#     'type': {'key': '/type/link'}},
#    {'title': 'New York Times review',
#     'url': 'http://www.nytimes.com/2001/07/29/books/books-in-brief-fiction-poetry-319619.html',
#     'type': {'key': '/type/link'}}],
#   'title': 'American Gods',
#   'covers': [8494659,
#    10211195,
#    9327686,
#    10289649,
#    10504245,
#    10708158,
#    10942037,
#    11351969,
#    12366417,
#    12370553,
#    12126280,
#    13449462,
#    13921325],
#   'subject_places': ['Chicago',
#    'Illinois (United States)',
#    'Chattanooga',
#    'Tennessee (United States)',
#    'Minnesota (United States)',
#    'Wisconsin (United States)',
#    'Rock City'],
#   'subjects': ['science fiction',
#    'fantasy fiction',
#    'Americana',
#    'fantasy',
#    'mythology',
#    'Spiritual warfare',
#    'Literature',
#    'award:hugo_award=2002',
#    'Ex-convicts',
#    'Fiction',
#    'Hugo Award Winner',
#    'New York Times bestseller',
#    'American National characteristics',
#    'Urban Fantasy',
#    'nyt:e-book_fiction=2012-01-14',
#    'award:hugo_award=novel',
#    'Widowers',
#    'Bodyguards',
#    'Roman',
#    'Amerikanisches Englisch',
#    'Fiction, fantasy, contemporary',
#    'Widowers, fiction',
#    'Widows, fiction',
#    'Coloring books',
#    'English fiction',
#    'Demonology',
#    'Spiritual life',
#    'New York Times reviewed',
#    'award:nebula_award=novel',
#    'Comics & graphic novels, fantasy',
#    'English literature',
#    'Características nacionales',
#    'Novela',
#    'Ex-détenus',
#    'Romans, nouvelles',
#    'Veufs',
#    'Gardes du corps',
#    'Combat spirituel',
#    'Gods'],
#   'subject_people': ['Shadow Moon',
#    'Mr. Wednesday',
#    'Spider',
#    'Anansi',
#    'Laura Moon',
#    'Hinzelmann',
#    'Easter',
#    'Whiskey Jack',
#    'Loki',
#    'Odin',
#    'Mr. Ibis',
#    'Samantha Black Crow',
#    'Bilquis',
#    'Media',
#    'Mad Sweeney',
#    'Czernobog',
#    'Mr. Jacquel',
#    'Mr. Nancy',
#    'Chad Mulligan',
#    'Margaret Black Crow',
#    'Mr. Town',
#    'Mr. World',
#    'Technical Boy'],
#   'key': '/works/OL679360W',
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}}],
#   'excerpts': [{'excerpt': 'Shadow had done three years in prison.',
#     'comment': 'first sentence',
#     'author': {'key': '/people/seabelis'}}],
#   'type': {'key': '/type/work'},
#   'location': '/works/OL679360W',
#   'latest_revision': 72,
#   'revision': 72,
#   'created': {'type': '/type/datetime', 'value': '2009-12-09T01:11:34.644230'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-03-19T17:37:10.245974'}},
#  {'title': 'American Gods',
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL13627230A'},
#     'type': {'key': '/type/author_role'}}],
#   'key': '/works/OL37899403W',
#   'type': {'key': '/type/work'},
#   'latest_revision': 1,
#   'revision': 1,
#   'created': {'type': '/type/datetime', 'value': '2024-02-24T19:15:24.775582'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-02-24T19:15:24.775582'}},
#  {'description': 'Neil Gaiman. Laura Lippman. Lee Child. These are just three of eighteen superstar authors who provide fascinating, thrilling, and utterly original perspectives on Sherlock Holmes in this one-of-a-kind book. These modern masters place the sleuth in suspenseful new situations, create characters who solve Holmesian mysteries, contemplate Holmes in his later years, fill gaps in the Sherlock Holmes Canon, and reveal their own personal obsessions with the Great Detective.\r\n\r\nThomas Perry, for example, has Dr. Watson tell his tale, in a virtuoso work of alternate history that finds President McKinley approaching the sleuth with a disturbing request; Lee Child sends an FBI agent to investigate a crime near today’s Baker Street—only to get a twenty-first-century shock; Jacqueline Winspear spins a story of a plucky boy inspired by the detective to make his own deductions; and graphic artist Colin Cotterill portrays his struggle to complete this assignment in his hilarious “The Mysterious Case of the Unwritten Short Story.”\r\n\r\nIn perfect tribute comes this delicious collection of twisty, clever, and enthralling studies of a timeless icon.',
#   'title': 'A Study in Sherlock',
#   'covers': [7087161, 8464125],
#   'subjects': ['Sherlock Holmes (Fictitious character)',
#    'American Detective and mystery stories',
#    'English Detective and mystery stories',
#    'Fiction',
#    'Sherlock Holmes (Fictional character)',
#    'Detective and mystery stories',
#    'Holmes, sherlock (fictitious character), fiction',
#    'Mystery',
#    'Sherlcok Holmes (Fictitious character)'],
#   'subject_people': ['Sherlock Holmes', 'John H. Watson'],
#   'key': '/works/OL15941727W',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1418880A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1434086A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL23367A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1387420A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL359237A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL451632A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL382863A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3326443A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL21825A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL27884A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL22029A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL6876269A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1389049A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL20985A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL4589221A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL8649662A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL34328A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3714098A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL8649663A'}},
#    {'author': {'key': '/authors/OL10716221A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2960301A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL10716222A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL10716223A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7245996A'},
#     'type': {'key': '/type/author_role'}}],
#   'type': {'key': '/type/work'},
#   'latest_revision': 16,
#   'revision': 16,
#   'created': {'type': '/type/datetime', 'value': '2011-07-26T20:28:27.998315'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-02-18T17:33:32.214622'}},
#  {'subjects': ["Children's stories, English",
#    "Children's stories, American",
#    "Children's stories"],
#   'key': '/works/OL21164187W',
#   'title': 'Midnight Feast',
#   'authors': [{'author': {'key': '/authors/OL92953A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1392395A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL304163A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL20100A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1394277A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL31309A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL588072A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL249804A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2623945A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL329632A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1423320A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL528888A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL29053A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL27229A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2632021A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1424877A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL31800A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL382982A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL33016A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL29282A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1392583A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL29219A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1389760A'},
#     'type': {'key': '/type/author_role'}}],
#   'type': {'key': '/type/work'},
#   'covers': [10330577],
#   'latest_revision': 8,
#   'revision': 8,
#   'created': {'type': '/type/datetime', 'value': '2020-08-08T14:56:34.248414'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-02-10T11:28:13.947022'}},
#  {'title': 'Scary! 2',
#   'covers': [8153298],
#   'subjects': ['American Horror tales',
#    'English Horror tales',
#    'English Short stories',
#    'American Short stories'],
#   'key': '/works/OL17852862W',
#   'type': {'key': '/type/work'},
#   'authors': [{'author': {'key': '/authors/OL501394A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL26545A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL35524A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL56244A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL19880A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL75116A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL161167A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2622181A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL4401825A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL31727A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL33088A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7416256A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}}],
#   'description': 'Video Nasty by Philip Pullman\r\nThe House Of No Return by R.L. Stine\r\nLost Hearts by M.R. James\r\nFinders Keepers by Anne McCaffrey\r\nThe Black Dress by Alison Prince\r\nThe Sussex Vampire by Arthur Conan Doyle\r\nCloud Cover by Robert Swindells\r\nThe Ghost Horse Of Genghis Khan by Russell Hoban\r\nHow 7 Went Mad by Bram Stoker\r\nKittens by Dean Koontz\r\nHorror Snap by Pete Johnson\r\nWhen We Went To See The End Of The World by Neil Gaiman',
#   'latest_revision': 7,
#   'revision': 7,
#   'created': {'type': '/type/datetime', 'value': '2018-03-27T07:23:41.980872'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-01-31T20:58:47.726642'}},
#  {'title': 'Crossing the Border',
#   'key': '/works/OL5112697W',
#   'authors': [{'author': {'key': '/authors/OL1126548A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL397484A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL23363A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL54959A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7564087A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL404614A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL12210880A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL6475682A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL22672A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL32981A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1070182A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7487563A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7504300A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2648754A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL896115A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL27110A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL422052A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL5542340A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2645138A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL4394862A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL230170A'},
#     'type': {'key': '/type/author_role'}}],
#   'type': {'key': '/type/work'},
#   'subjects': ['Erotic stories',
#    'English Erotic stories',
#    'American Erotic stories',
#    'English Short stories'],
#   'covers': [12175544, 1003513],
#   'subtitle': 'Tales of Erotic Ambiguity',
#   'latest_revision': 5,
#   'revision': 5,
#   'created': {'type': '/type/datetime', 'value': '2009-12-10T08:41:23.860776'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-01-28T10:31:35.270766'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Canallas',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2830895A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL20934A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2801083A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1126548A'}}],
#   'key': '/works/OL29864741W',
#   'latest_revision': 6,
#   'revision': 6,
#   'created': {'type': '/type/datetime', 'value': '2022-11-23T03:42:18.619452'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-01-21T14:54:08.782118'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Riding the Nightmare',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1126548A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL36338114W',
#   'latest_revision': 4,
#   'revision': 4,
#   'created': {'type': '/type/datetime', 'value': '2023-07-18T08:27:14.543415'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-01-09T21:01:18.365913'}},
#  {'subjects': ['FICTION / Action & Adventure',
#    'FICTION / Fantasy / Short Stories',
#    'FICTION / Suspense',
#    'American Short stories',
#    'American fiction',
#    'Rogues and vagabonds',
#    'Fiction',
#    'nyt:hardcover-fiction=2014-07-06',
#    'New York Times bestseller',
#    'Short stories, american',
#    'American fiction (collections), 21st century',
#    'Fantasy fiction'],
#   'key': '/works/OL19287425W',
#   'title': 'Rogues',
#   'authors': [{'author': {'key': '/authors/OL234664A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL237141A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2801083A'},
#     'type': {'key': '/type/author_role'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1433006A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2830895A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL10857027A'}}],
#   'type': {'key': '/type/work'},
#   'covers': [14543457],
#   'latest_revision': 13,
#   'revision': 13,
#   'created': {'type': '/type/datetime', 'value': '2019-03-13T06:23:01.331533'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-01-05T20:24:10.040936'}},
#  {'title': 'Shadows over Innsmouth',
#   'covers': [4832551, 210202, 8762165, 8755557],
#   'first_publish_date': 'October 1994',
#   'key': '/works/OL1840315W',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL220396A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL92514A'}},
#    {'author': {'key': '/authors/OL33034A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL320767A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL24098A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL39331A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1782636A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL5624260A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1625827A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1562329A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL844878A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2648754A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2645208A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL22161A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL10220907A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL220575A'},
#     'type': {'key': '/type/author_role'}}],
#   'type': {'key': '/type/work'},
#   'subject_places': ['Massachusetts'],
#   'subjects': ['English Fantasy fiction',
#    'Paranormal fiction',
#    'English Horror tales',
#    'Harbors',
#    'Fiction',
#    'English Short stories',
#    'Science fiction, english',
#    'Fantasy fiction',
#    'Short stories, english',
#    'Fiction, horror'],
#   'latest_revision': 5,
#   'revision': 5,
#   'created': {'type': '/type/datetime', 'value': '2009-12-09T22:27:00.312120'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-03-10T10:45:37.148983'}},
#  {'title': 'A Mountain Walked: Great Tales of the Cthulhu Mythos',
#   'covers': [8747587, 8763386],
#   'key': '/works/OL20071249W',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2755616A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7617317A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7617318A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL6565372A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL6868205A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL220396A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7617319A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL534271A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL397402A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1295287A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7479035A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3007139A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL29758A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2827567A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3745857A'}}],
#   'type': {'key': '/type/work'},
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2019-07-28T06:53:44.183890'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-01-03T18:41:30.769952'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Fearie Tales [signed traycased edition]',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL220396A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL25453A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7206029A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL10337083A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL220575A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL6815968A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7503550A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL24098A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL382982A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7850947A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL10652771A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL636115A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL10652772A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL9145261A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL10367814A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7958794A'}}],
#   'key': '/works/OL28774667W',
#   'latest_revision': 5,
#   'revision': 5,
#   'created': {'type': '/type/datetime', 'value': '2022-09-15T17:17:00.189016'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2024-01-03T18:29:39.707962'}},
#  {'subjects': ['Individuality',
#    'First day of school',
#    'Schools',
#    'Juvenile fiction',
#    'Pandas',
#    'Fiction',
#    'Animals',
#    'Ability',
#    "Children's fiction",
#    'Pandas, fiction',
#    'First day of school, fiction',
#    'Animals, fiction',
#    'Picture books',
#    'Child and youth fiction'],
#   'key': '/works/OL17485977W',
#   'title': "Chu's First Day of School",
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}}],
#   'type': {'key': '/type/work'},
#   'covers': [7673760, 8156482, 8905822, 10330322, 12341081],
#   'latest_revision': 11,
#   'revision': 11,
#   'created': {'type': '/type/datetime', 'value': '2016-10-14T12:54:06.669184'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-31T20:52:37.732900'}},
#  {'description': '"Chu the panda goes to the beach!"--\r\n\r\nAccompanying his family on a visit to the beach, Chu the little panda looks forward to playing in the sand and wading in the water while wondering how his colossal sneezes will impact the day.',
#   'covers': [9614604, 10868216, 10893679, 12245418],
#   'key': '/works/OL19998020W',
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}}],
#   'title': "Chu's day at the beach",
#   'subjects': ['Sneezing',
#    'Pandas',
#    'Beaches',
#    'Fiction',
#    "Children's stories",
#    'Juvenile fiction',
#    'Pictorial works',
#    'JUVENILE FICTION / General',
#    'JUVENILE FICTION / Animals / General',
#    'JUVENILE FICTION / Family / General (see also headings under Social Issues)',
#    "Children's fiction",
#    'Pandas, fiction',
#    'Picture books'],
#   'type': {'key': '/type/work'},
#   'latest_revision': 10,
#   'revision': 10,
#   'created': {'type': '/type/datetime', 'value': '2019-07-18T20:12:06.181435'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-31T20:51:19.647225'}},
#  {'description': 'Chu is a little panda with a big sneeze. When Chu sneezes, bad things happen. But as Chu and his parents visit the library, the diner, and the circus, will anyone hear Chu when he starts to feel a familiar tickle in his nose?',
#   'covers': [7268012, 7538654, 7705265, 10893673, 12387924, 12239330],
#   'key': '/works/OL16810272W',
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}}],
#   'title': "Chu's Day",
#   'subjects': ['Juvenile fiction',
#    'Sneezing',
#    'Pandas',
#    'Fiction',
#    'Ficción juvenil',
#    'Osos Pandas',
#    'Spanish language materials',
#    'nyt:picture-books=2013-01-27',
#    'New York Times bestseller',
#    'Parents et enfants',
#    'Romans, nouvelles, etc. pour la jeunesse',
#    'Inquiétude',
#    'Bibliothèques',
#    'Restaurants',
#    'Cirque',
#    'Éternuement',
#    'Eternuement',
#    "Children's fiction",
#    'Pandas, fiction',
#    'Toy and movable books'],
#   'type': {'key': '/type/work'},
#   'location': '/works/OL16810272W',
#   'latest_revision': 16,
#   'revision': 16,
#   'created': {'type': '/type/datetime', 'value': '2013-12-21T16:57:41.757423'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-31T20:50:38.549569'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Statesmanship',
#   'authors': [{'author': {'key': '/authors/OL118077A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL13066A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1510013A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL54959A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL19450A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2623606A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL6898863A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL217115A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL560261A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2395992A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7919580A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL104867A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL6496199A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2822822A'},
#     'type': {'key': '/type/author_role'}}],
#   'covers': [11121558],
#   'key': '/works/OL24500055W',
#   'latest_revision': 15,
#   'revision': 15,
#   'created': {'type': '/type/datetime', 'value': '2021-05-19T00:48:25.765583'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-27T23:26:52.993539'}},
#  {'description': '"The joy of fiction is the joy of the imagination. . . ."The best stories pull readers in and keep them turning the pages, eager to discover more—to find the answer to the question: "And then what happened?" The true hallmark of great literature is great imagination, and as Neil Gaiman and Al Sarrantonio prove with this outstanding collection, when it comes to great fiction, all genres are equal.Stories is a groundbreaking anthology that reinvigorates, expands, and redefines the limits of imaginative fiction and affords some of the best writers in the world—from Peter Straub and Chuck Palahniuk to Roddy Doyle and Diana Wynne Jones, Stewart O\'Nan and Joyce Carol Oates to Walter Mosley and Jodi Picoult—the opportunity to work together, defend their craft, and realign misconceptions. Gaiman, a literary magician whose acclaimed work defies easy categorization and transcends all boundaries, and "master anthologist" (Booklist) Sarrantonio personally invited, read, and selected all the stories in this collection, and their standard for this "new literature of the imagination" is high. "We wanted to read stories that used a lightning-flash of magic as a way of showing us something we have already seen a thousand times as if we have never seen it at all."Joe Hill boldly aligns theme and form in his disturbing tale of a man\'s descent into evil in "Devil on the Staircase." In "Catch and Release," Lawrence Block tells of a seasoned fisherman with a talent for catching a bite of another sort. Carolyn Parkhurst adds a dark twist to sibling rivalry in "Unwell." Joanne Harris weaves a tale of ancient gods in modern New York in "Wildfire in Manhattan." Vengeance is the heart of Richard Adams\'s "The Knife." Jeffery Deaver introduces a dedicated psychologist whose mission in life is to save people in "The Therapist." A chilling punishment befitting an unspeakable crime is at the dark heart of Neil Gaiman\'s novelette "The Truth Is a Cave in the Black Mountains."As it transforms your view of the world, this brilliant and visionary volume—sure to become a classic—will ignite a new appreciation for the limitless realm of exceptional fiction.',
#   'title': 'Stories',
#   'covers': [6430935, 8329700, 8446224, 9096768, 10133032],
#   'subjects': ['Fiction',
#    'Literature',
#    'American Short stories',
#    'American fiction',
#    'English Short stories',
#    'English fiction',
#    'Fiction, short stories (single author)',
#    'Short stories, english',
#    'Short stories, american'],
#   'key': '/works/OL15173350W',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL711630A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL24388A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL32981A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL25453A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL220575A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL19593A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3154806A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL800926A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL78925A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL39102A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL32650A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL21255A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL26171A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL24312A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL31384A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL29711A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL4399471A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1431347A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7290605A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL26982A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2659519A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL40077A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL579159A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL394285A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL218450A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2631898A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL8647562A'}}],
#   'subject_times': ['21st century'],
#   'type': {'key': '/type/work'},
#   'latest_revision': 15,
#   'revision': 15,
#   'created': {'type': '/type/datetime', 'value': '2010-06-30T03:27:30.304555'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-22T07:57:40.698384'}},
#  {'subjects': ['Vampires', 'Fiction', 'Fiction, fantasy, historical'],
#   'key': '/works/OL15168890W',
#   'title': 'By Blood We Live',
#   'authors': [{'author': {'key': '/authors/OL7207957A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL39486A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL23207A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL292141A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL3003153A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL3023955A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL382982A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2711187A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL246532A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL381615A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL3042054A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1606907A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL9689655A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL220575A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL40965A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL18722A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7752487A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL23918A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL9080029A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL397402A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1394972A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2645208A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL36575A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1432654A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2711189A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7159378A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL340770A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL33124A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL577531A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL24812A'},
#     'type': {'key': '/type/author_role'}}],
#   'type': {'key': '/type/work'},
#   'covers': [6426138],
#   'latest_revision': 7,
#   'revision': 7,
#   'created': {'type': '/type/datetime', 'value': '2010-06-28T01:51:41.310258'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-16T23:26:58.032622'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Psychos',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2787131A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL21255A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL24137A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL9107558A'}}],
#   'key': '/works/OL28815981W',
#   'latest_revision': 4,
#   'revision': 4,
#   'created': {'type': '/type/datetime', 'value': '2022-09-18T01:01:11.861234'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-16T22:48:40.707319'}},
#  {'description': '"There has never been anything like this before, and there will never be anything like this again…[Thurber] takes such delight in the words. It\'s like it\'s written by somebody who wants to infect you with his love of words. There are poems hidden in the text. There are places where it wanders into rhyme and out again. There are all of the invented words. The story itself is nonsense in the finest possible way." —Neil Gaiman, interviewed in The Wall Street Journal',
#   'title': 'The 13 Clocks',
#   'covers': [5020685, 12372535],
#   'first_publish_date': '1950',
#   'key': '/works/OL14857157W',
#   'authors': [{'author': {'key': '/authors/OL20903A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL30490A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}}],
#   'dewey_number': ['[Fic]'],
#   'type': {'key': '/type/work'},
#   'subjects': ['Fiction',
#    'Uncles',
#    'Princesses',
#    'Minstrels',
#    'Time',
#    'Clocks and watches',
#    'Fairy tales',
#    'Juvenile fiction',
#    'Princes',
#    "Children's literature",
#    "Children's fiction",
#    'Time, fiction',
#    'Princesses, fiction',
#    'Clocks and watches, fiction',
#    'Poets, fiction',
#    'Family, fiction'],
#   'latest_revision': 16,
#   'revision': 16,
#   'created': {'type': '/type/datetime', 'value': '2009-12-07T22:14:58.437586'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:26:09.933230'}},
#  {'subjects': ['Literature', 'COMICS & GRAPHIC NOVELS / Fantasy'],
#   'key': '/works/OL20174446W',
#   'title': 'Absolute Sandman Overture',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2943948A'}}],
#   'type': {'key': '/type/work'},
#   'covers': [8821307],
#   'latest_revision': 5,
#   'revision': 5,
#   'created': {'type': '/type/datetime', 'value': '2019-10-06T08:26:04.532589'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:24:42.675078'}},
#  {'type': {'key': '/type/work'},
#   'title': "L'al.lucinant, galàctic i piràtic viatge del pare",
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}}],
#   'covers': [14080290, 14080291],
#   'key': '/works/OL35096963W',
#   'latest_revision': 4,
#   'revision': 4,
#   'created': {'type': '/type/datetime', 'value': '2023-04-17T05:13:47.250063'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:24:09.478510'}},
#  {'description': {'type': '/type/text',
#    'value': 'As two children and their pet gazelle sneak out of the house in search of treasure, they come across a world beneath the city that is inhabited with monsters and pirates.'},
#   'covers': [2312222],
#   'key': '/works/OL679339W',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1395453A'}}],
#   'title': 'The Dangerous Alphabet',
#   'subjects': ['Fiction',
#    'Underground areas',
#    'Pirates',
#    'Adventure and adventurers',
#    'Alphabet',
#    'Juvenile fiction',
#    'Stories in rhyme',
#    'Monsters',
#    'Pirates -- Fiction',
#    'Adventure stories',
#    'Underground architecture',
#    'Adventure fiction',
#    'nyt:picture-books=2008-07-06',
#    'New York Times bestseller',
#    "Children's fiction",
#    'Pirates, fiction',
#    'Monsters, fiction',
#    'Adventure and adventurers, fiction',
#    'Alphabet books',
#    'Buried treasure, fiction'],
#   'type': {'key': '/type/work'},
#   'latest_revision': 13,
#   'revision': 13,
#   'created': {'type': '/type/datetime', 'value': '2009-12-09T01:11:34.644230'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:21:21.047369'}},
#  {'title': 'Dustcovers',
#   'covers': [3746518, 13598489],
#   'subject_places': ['United States', 'Great Britain'],
#   'subjects': ['Sandman (Comic strip)',
#    'History',
#    'Graphic novels',
#    'Book jackets',
#    'Comic book covers',
#    'Comic books, strips',
#    'Illustrations'],
#   'subject_people': ['Dave McKean'],
#   'key': '/works/OL679325W',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'author': {'key': '/authors/OL219070A'},
#     'type': {'key': '/type/author_role'}}],
#   'subject_times': ['20th century'],
#   'type': {'key': '/type/work'},
#   'latest_revision': 7,
#   'revision': 7,
#   'created': {'type': '/type/datetime', 'value': '2009-12-09T01:11:34.644230'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:20:27.953966'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Miracleman de Neil Gaiman y Mark Buckingham 1',
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2864353A'},
#     'type': {'key': '/type/author_role'}}],
#   'covers': [14203953, 14203952, 14203954, 14203955],
#   'key': '/works/OL35189818W',
#   'latest_revision': 4,
#   'revision': 4,
#   'created': {'type': '/type/datetime', 'value': '2023-04-20T00:06:45.644878'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:20:14.023190'}},
#  {'title': 'Neil Gaiman Reader',
#   'key': '/works/OL21891230W',
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}}],
#   'type': {'key': '/type/work'},
#   'subjects': ['Fiction, magical realism',
#    'Fiction, short stories (single author)',
#    'English Fantasy fiction',
#    'English Short stories',
#    'English literature'],
#   'covers': [13625274, 12457139],
#   'latest_revision': 7,
#   'revision': 7,
#   'created': {'type': '/type/datetime', 'value': '2020-09-01T01:40:10.234376'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:19:21.822403'}},
#  {'description': {'type': '/type/text',
#    'value': '"From the Hugo, Bram Stoker, Locus, World Fantasy, and Nebula award-winning, and New York Times bestselling writer Neil Gaiman (American Gods), this fantasy story blends the worlds of H.P. Lovecraft and Roger Zelazny. This new edition of Only the End of the World Again features a brand new cover, in a new deluxe hardcover format; with bonus material including high res scans of the inks and layouts. The story features an adjustor, Lawrence Talbot who recently sets up shop in Innsmouth only to discover that the world may be ending and that the instrument of destruction is a werewolf"--\n\n"An adjustor discovers that the world may be ending and that the instrument of destruction is a werewolf"--'},
#   'covers': [954282],
#   'key': '/works/OL679301W',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL6593325A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3104527A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL10669235A'}}],
#   'title': 'Only the end of the world again',
#   'subjects': ['Werewolves',
#    'Comic books, strips',
#    'End of the world',
#    'Literature'],
#   'type': {'key': '/type/work'},
#   'latest_revision': 8,
#   'revision': 8,
#   'created': {'type': '/type/datetime', 'value': '2009-12-09T01:11:34.644230'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:17:56.717970'}},
#  {'title': 'The Problem of Susan and Other Stories',
#   'covers': [8808920, 14021989],
#   'key': '/works/OL20162917W',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL282954A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1398733A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3017370A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL5464219A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7992933A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7040892A'}}],
#   'type': {'key': '/type/work'},
#   'subjects': ['Literature'],
#   'latest_revision': 4,
#   'revision': 4,
#   'created': {'type': '/type/datetime', 'value': '2019-10-04T22:45:46.995800'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:17:10.138000'}},
#  {'type': {'key': '/type/work'},
#   'title': 'El puente del Troll',
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL1075218A'},
#     'type': {'key': '/type/author_role'}}],
#   'covers': [14022787, 14022786],
#   'key': '/works/OL35052410W',
#   'latest_revision': 5,
#   'revision': 5,
#   'created': {'type': '/type/datetime', 'value': '2023-04-15T18:24:34.057457'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T21:16:36.353908'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Bons averanys',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL25712A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'covers': [13934443],
#   'key': '/works/OL34981844W',
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2023-04-13T10:44:44.232146'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T19:25:07.780615'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Mitos nórdicos nº 02/03',
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7992933A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2864353A'},
#     'type': {'key': '/type/author_role'}}],
#   'covers': [14021987, 14021988],
#   'key': '/works/OL35051745W',
#   'description': {'type': '/type/text',
#    'value': 'Recopila los números 1 a 6 de Mitos nórdicos II, ilustrados por Matt Horak, Mark Buckingham, Gabriel Hernández Walta y Sandy Jarrell.'},
#   'latest_revision': 5,
#   'revision': 5,
#   'created': {'type': '/type/datetime', 'value': '2023-04-15T18:00:13.122166'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-12-15T17:13:23.649099'}},
#  {'type': {'key': '/type/work'},
#   'title': 'La última tentación',
#   'authors': [{'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL2942286A'},
# ...
#     'author': {'key': '/authors/OL1399676A'}}],
#   'covers': [13477257],
#   'key': '/works/OL34753371W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2023-03-16T00:18:17.698146'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Sandman',
#   'subjects': ['Literature'],
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1399676A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2710887A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2660536A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1483720A'}}],
#   'key': '/works/OL31128575W',
#   'covers': [13914410],
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2022-12-03T12:04:00.132063'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-04-12T21:15:53.327586'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Mites Nòrdics',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7932826A'}}],
#   'covers': [13652030],
#   'key': '/works/OL34862166W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2023-03-19T08:09:19.715288'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': "Neil Gaiman's Likely Stories",
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2864353A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL5359796A'}}],
#   'key': '/works/OL28828434W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-09-18T07:21:20.714335'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Tori Amos Little Earthquakes Variant Cover',
#   'subjects': ['Comics & graphic novels, general'],
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1484192A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL52922A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3948530A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3048714A'}}],
#   'key': '/works/OL29331487W',
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2022-11-17T07:13:28.593938'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'STARDUST 4 -D-',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL670446A'}}],
#   'key': '/works/OL31253856W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-12-04T15:22:17.127224'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Mitos nórdicos nº 01/03',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7992933A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2793334A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL6585286A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL614504A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1798396A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7040892A'}}],
#   'key': '/works/OL28332703W',
#   'covers': [12824041],
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2022-07-18T11:31:41.459929'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': "Sandman 08 - Worlds' End : Bd. 8",
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL31223022W',
#   'covers': [14514876],
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2022-12-04T07:21:00.814592'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-10-24T04:13:05.055617'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Libro Del Cementerio/ the Graveyard Book',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL32483073W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-12-17T21:02:34.759305'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Tales of Mystery and Imagination',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL10603905A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7840740A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL28616043W',
#   'covers': [13217562],
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2022-08-17T07:24:04.823226'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': "Neil Gaiman's a Study in Emerald",
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3863529A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7633128A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2872020A'}}],
#   'key': '/works/OL28828366W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-09-18T07:19:39.317204'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Blood Bank',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7583529A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL3027409A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL8225117A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7485067A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL11431059A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL1519822A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL8363228A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL9365779A'}}],
#   'key': '/works/OL31341625W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-12-06T15:28:20.291884'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'AMERİKAN TANRILARI',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL31967754W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-12-10T09:03:43.019897'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Interworld',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL29239367W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-10-26T22:17:18.392922'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': "Neil Gaiman's Troll Bridge",
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL28826973W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-09-18T06:36:47.895827'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Gwiezdny pył',
#   'subjects': ['Powieść fantastyczna angielska', 'Tłumaczenia polskie'],
#   'subject_times': ['1990-'],
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'covers': [13022955],
#   'key': '/works/OL31212717W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-12-04T03:27:41.117716'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Bioluminescent',
#   'subjects': ['Fiction, science fiction, general',
#    'Fiction, anthologies (multiple authors)',
#    'solarpunk'],
#   'authors': [{'author': {'key': '/authors/OL10394934A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL53305A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL7501009A'},
#     'type': {'key': '/type/author_role'}},
#    {'author': {'key': '/authors/OL10802936A'},
#     'type': {'key': '/type/author_role'}}],
#   'key': '/works/OL29204484W',
#   'description': {'type': '/type/text',
#    'value': "Solarpunk communities that glow when the sun goes down. Witches on distant planets and future pagans building resilient ecotopias. The search for hope in a better world. Evolution and transformation. Exploration and discovery. The pages of this book are filled with wonders both technological and magical. Conflicts lead to resilience and solutions both internal and community-based. Stories span from the terrestrial to the galactic to the inner-depths of memory and imagination.\r\n\r\nFeaturing work by Starhawk, Sarena Ulibarri, Wendy N. Wagner, Neil Gaiman, Justine Norton-Kertson, Yasmin Moita, J.D. Harklock, BrightFlame, Pedro Inguez, and more, twenty-two authors take a variety of different paths as they begin to map out the new and budding lunarpunk genre's terrain. Join them in adventures through glowing utopian worlds where people work together and do their best to build a better for us all. Join the, and explore Lunarpunk."},
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2022-10-20T01:01:35.151616'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Creatures of the Night (Second Edition)',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL28828915W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-09-18T07:35:24.977849'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Dym i lustra',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'covers': [13332556],
#   'key': '/works/OL34532681W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2023-02-23T21:47:38.507991'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': "Sandman - World'S End",
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL34566501W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2023-02-27T22:26:16.002598'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'El océano al final del camino',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL7992934A'}}],
#   'covers': [13449791],
#   'key': '/works/OL34736429W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2023-03-15T09:27:35.821827'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Coraline',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'covers': [13532781],
#   'key': '/works/OL34784897W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2023-03-16T22:41:39.618694'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': "Yoshitaka Amano's HERO Party of One Definitive Edition",
#   'subjects': ['Comics & graphic novels, fantasy',
#    'Fiction, action & adventure'],
#   'key': '/works/OL28810247W',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2629923A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-09-17T21:34:23.101729'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Untitled Gaiman 1',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL32396752W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-12-17T08:51:15.242967'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'The Sandman',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}},
#    {'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL2622187A'}}],
#   'key': '/works/OL28604758W',
#   'subjects': ['Comics & graphic novels, fantasy'],
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2022-08-10T10:09:40.842380'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Mirrormask',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'covers': [13119811],
#   'key': '/works/OL33138627W',
#   'latest_revision': 2,
#   'revision': 2,
#   'created': {'type': '/type/datetime', 'value': '2022-12-28T22:25:00.952330'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-03-19T17:38:48.118928'}},
#  {'type': {'key': '/type/work'},
#   'title': 'Coisas Frageis 2',
#   'authors': [{'type': {'key': '/type/author_role'},
#     'author': {'key': '/authors/OL53305A'}}],
#   'key': '/works/OL28957607W',
#   'covers': [14121133],
#   'latest_revision': 3,
#   'revision': 3,
#   'created': {'type': '/type/datetime', 'value': '2022-10-08T03:56:04.875914'},
#   'last_modified': {'type': '/type/datetime',
#    'value': '2023-04-18T06:05:07.577012'}}]

# %%
# Now we have 150 book objects, 
# which we got by making 3 requests to the API.
print(f'We have {len(response_json)} books!')
# Out:
# We have 150 books!

# %%
# preview the JSON
print(json.dumps(response_json, indent=4))
# Out:
# [
#     {
#         "description": "American Gods (2001) is a fantasy novel by British author Neil Gaiman. The novel is a blend of Americana, fantasy, and various strands of ancient and modern mythology, all centering on the mysterious and taciturn Shadow.",
#         "links": [
#             {
#                 "title": "Neil Gaiman | Neil's Work | Books | American Gods",
#                 "url": "http://www.neilgaiman.com/works/Books/American+Gods/ed/102/",
#                 "type": {
#                     "key": "/type/link"
#                 }
#             },
#             {
#                 "title": "American Gods - Wikipedia",
#                 "url": "https://en.wikipedia.org/wiki/American_Gods",
#                 "type": {
#                     "key": "/type/link"
#                 }
#             },
#             {
#                 "title": "publishersweekly.com/978-0-380-97365-1",
#                 "url": "https://www.publishersweekly.com/978-0-380-97365-1",
#                 "type": {
#                     "key": "/type/link"
#                 }
#             },
#             {
#                 "title": "Neil Gaiman, \u201cAmerican Gods: The Tenth Anniversary Edition\u201d",
#                 "url": "https://www.newyorker.com/recommends/listen/american-gods-the-tenth-anniversary-edition",
#                 "type": {
#                     "key": "/type/link"
#                 }
#             },
#             {
#                 "title": "New York Times review",
#                 "url": "http://www.nytimes.com/2001/07/29/books/books-in-brief-fiction-poetry-319619.html",
#                 "type": {
#                     "key": "/type/link"
#                 }
#             }
#         ],
#         "title": "American Gods",
#         "covers": [
#             8494659,
#             10211195,
#             9327686,
#             10289649,
#             10504245,
#             10708158,
#             10942037,
#             11351969,
#             12366417,
#             12370553,
#             12126280,
#             13449462,
#             13921325
#         ],
#         "subject_places": [
#             "Chicago",
#             "Illinois (United States)",
#             "Chattanooga",
#             "Tennessee (United States)",
#             "Minnesota (United States)",
#             "Wisconsin (United States)",
#             "Rock City"
#         ],
#         "subjects": [
#             "science fiction",
#             "fantasy fiction",
#             "Americana",
#             "fantasy",
#             "mythology",
#             "Spiritual warfare",
#             "Literature",
#             "award:hugo_award=2002",
#             "Ex-convicts",
#             "Fiction",
#             "Hugo Award Winner",
#             "New York Times bestseller",
#             "American National characteristics",
#             "Urban Fantasy",
#             "nyt:e-book_fiction=2012-01-14",
#             "award:hugo_award=novel",
#             "Widowers",
#             "Bodyguards",
#             "Roman",
#             "Amerikanisches Englisch",
#             "Fiction, fantasy, contemporary",
#             "Widowers, fiction",
#             "Widows, fiction",
#             "Coloring books",
#             "English fiction",
#             "Demonology",
#             "Spiritual life",
#             "New York Times reviewed",
#             "award:nebula_award=novel",
#             "Comics & graphic novels, fantasy",
#             "English literature",
#             "Caracter\u00edsticas nacionales",
#             "Novela",
#             "Ex-d\u00e9tenus",
#             "Romans, nouvelles",
#             "Veufs",
#             "Gardes du corps",
#             "Combat spirituel",
#             "Gods"
#         ],
#         "subject_people": [
#             "Shadow Moon",
#             "Mr. Wednesday",
#             "Spider",
#             "Anansi",
#             "Laura Moon",
#             "Hinzelmann",
#             "Easter",
#             "Whiskey Jack",
#             "Loki",
#             "Odin",
#             "Mr. Ibis",
#             "Samantha Black Crow",
#             "Bilquis",
#             "Media",
#             "Mad Sweeney",
#             "Czernobog",
#             "Mr. Jacquel",
#             "Mr. Nancy",
#             "Chad Mulligan",
#             "Margaret Black Crow",
#             "Mr. Town",
#             "Mr. World",
#             "Technical Boy"
#         ],
#         "key": "/works/OL679360W",
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "excerpts": [
#             {
#                 "excerpt": "Shadow had done three years in prison.",
#                 "comment": "first sentence",
#                 "author": {
#                     "key": "/people/seabelis"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "location": "/works/OL679360W",
#         "latest_revision": 72,
#         "revision": 72,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2009-12-09T01:11:34.644230"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-03-19T17:37:10.245974"
#         }
#     },
#     {
#         "title": "American Gods",
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL13627230A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "key": "/works/OL37899403W",
#         "type": {
#             "key": "/type/work"
#         },
#         "latest_revision": 1,
#         "revision": 1,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2024-02-24T19:15:24.775582"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-02-24T19:15:24.775582"
#         }
#     },
#     {
#         "description": "Neil Gaiman. Laura Lippman. Lee Child. These are just three of eighteen superstar authors who provide fascinating, thrilling, and utterly original perspectives on Sherlock Holmes in this one-of-a-kind book. These modern masters place the sleuth in suspenseful new situations, create characters who solve Holmesian mysteries, contemplate Holmes in his later years, fill gaps in the Sherlock Holmes Canon, and reveal their own personal obsessions with the Great Detective.\r\n\r\nThomas Perry, for example, has Dr. Watson tell his tale, in a virtuoso work of alternate history that finds President McKinley approaching the sleuth with a disturbing request; Lee Child sends an FBI agent to investigate a crime near today\u2019s Baker Street\u2014only to get a twenty-first-century shock; Jacqueline Winspear spins a story of a plucky boy inspired by the detective to make his own deductions; and graphic artist Colin Cotterill portrays his struggle to complete this assignment in his hilarious \u201cThe Mysterious Case of the Unwritten Short Story.\u201d\r\n\r\nIn perfect tribute comes this delicious collection of twisty, clever, and enthralling studies of a timeless icon.",
#         "title": "A Study in Sherlock",
#         "covers": [
#             7087161,
#             8464125
#         ],
#         "subjects": [
#             "Sherlock Holmes (Fictitious character)",
#             "American Detective and mystery stories",
#             "English Detective and mystery stories",
#             "Fiction",
#             "Sherlock Holmes (Fictional character)",
#             "Detective and mystery stories",
#             "Holmes, sherlock (fictitious character), fiction",
#             "Mystery",
#             "Sherlcok Holmes (Fictitious character)"
#         ],
#         "subject_people": [
#             "Sherlock Holmes",
#             "John H. Watson"
#         ],
#         "key": "/works/OL15941727W",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1418880A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1434086A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL23367A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1387420A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL359237A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL451632A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL382863A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL3326443A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL21825A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL27884A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL22029A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL6876269A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1389049A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL20985A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL4589221A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL8649662A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL34328A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL3714098A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL8649663A"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL10716221A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2960301A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL10716222A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL10716223A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7245996A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "latest_revision": 16,
#         "revision": 16,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2011-07-26T20:28:27.998315"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-02-18T17:33:32.214622"
#         }
#     },
#     {
#         "subjects": [
#             "Children's stories, English",
#             "Children's stories, American",
#             "Children's stories"
#         ],
#         "key": "/works/OL21164187W",
#         "title": "Midnight Feast",
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL92953A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1392395A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL304163A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL20100A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1394277A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL31309A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL588072A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL249804A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2623945A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL329632A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1423320A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL528888A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL29053A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL27229A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2632021A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1424877A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL31800A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL382982A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL33016A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL29282A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1392583A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL29219A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1389760A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "covers": [
#             10330577
#         ],
#         "latest_revision": 8,
#         "revision": 8,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2020-08-08T14:56:34.248414"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-02-10T11:28:13.947022"
#         }
#     },
#     {
#         "title": "Scary! 2",
#         "covers": [
#             8153298
#         ],
#         "subjects": [
#             "American Horror tales",
#             "English Horror tales",
#             "English Short stories",
#             "American Short stories"
#         ],
#         "key": "/works/OL17852862W",
#         "type": {
#             "key": "/type/work"
#         },
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL501394A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL26545A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL35524A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL56244A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL19880A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL75116A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL161167A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2622181A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL4401825A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL31727A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL33088A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7416256A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "description": "Video Nasty by Philip Pullman\r\nThe House Of No Return by R.L. Stine\r\nLost Hearts by M.R. James\r\nFinders Keepers by Anne McCaffrey\r\nThe Black Dress by Alison Prince\r\nThe Sussex Vampire by Arthur Conan Doyle\r\nCloud Cover by Robert Swindells\r\nThe Ghost Horse Of Genghis Khan by Russell Hoban\r\nHow 7 Went Mad by Bram Stoker\r\nKittens by Dean Koontz\r\nHorror Snap by Pete Johnson\r\nWhen We Went To See The End Of The World by Neil Gaiman",
#         "latest_revision": 7,
#         "revision": 7,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2018-03-27T07:23:41.980872"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-01-31T20:58:47.726642"
#         }
#     },
#     {
#         "title": "Crossing the Border",
#         "key": "/works/OL5112697W",
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL1126548A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL397484A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL23363A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL54959A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7564087A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL404614A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL12210880A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL6475682A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL22672A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL32981A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1070182A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7487563A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7504300A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2648754A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL896115A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL27110A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL422052A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL5542340A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2645138A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL4394862A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL230170A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "subjects": [
#             "Erotic stories",
#             "English Erotic stories",
#             "American Erotic stories",
#             "English Short stories"
#         ],
#         "covers": [
#             12175544,
#             1003513
#         ],
#         "subtitle": "Tales of Erotic Ambiguity",
#         "latest_revision": 5,
#         "revision": 5,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2009-12-10T08:41:23.860776"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-01-28T10:31:35.270766"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Canallas",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2830895A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL20934A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2801083A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1126548A"
#                 }
#             }
#         ],
#         "key": "/works/OL29864741W",
#         "latest_revision": 6,
#         "revision": 6,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-11-23T03:42:18.619452"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-01-21T14:54:08.782118"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Riding the Nightmare",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1126548A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL36338114W",
#         "latest_revision": 4,
#         "revision": 4,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-07-18T08:27:14.543415"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-01-09T21:01:18.365913"
#         }
#     },
#     {
#         "subjects": [
#             "FICTION / Action & Adventure",
#             "FICTION / Fantasy / Short Stories",
#             "FICTION / Suspense",
#             "American Short stories",
#             "American fiction",
#             "Rogues and vagabonds",
#             "Fiction",
#             "nyt:hardcover-fiction=2014-07-06",
#             "New York Times bestseller",
#             "Short stories, american",
#             "American fiction (collections), 21st century",
#             "Fantasy fiction"
#         ],
#         "key": "/works/OL19287425W",
#         "title": "Rogues",
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL234664A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL237141A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2801083A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1433006A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2830895A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL10857027A"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "covers": [
#             14543457
#         ],
#         "latest_revision": 13,
#         "revision": 13,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2019-03-13T06:23:01.331533"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-01-05T20:24:10.040936"
#         }
#     },
#     {
#         "title": "Shadows over Innsmouth",
#         "covers": [
#             4832551,
#             210202,
#             8762165,
#             8755557
#         ],
#         "first_publish_date": "October 1994",
#         "key": "/works/OL1840315W",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL220396A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL92514A"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL33034A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL320767A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL24098A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL39331A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1782636A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL5624260A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1625827A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1562329A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL844878A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2648754A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2645208A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL22161A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL10220907A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL220575A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "subject_places": [
#             "Massachusetts"
#         ],
#         "subjects": [
#             "English Fantasy fiction",
#             "Paranormal fiction",
#             "English Horror tales",
#             "Harbors",
#             "Fiction",
#             "English Short stories",
#             "Science fiction, english",
#             "Fantasy fiction",
#             "Short stories, english",
#             "Fiction, horror"
#         ],
#         "latest_revision": 5,
#         "revision": 5,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2009-12-09T22:27:00.312120"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-03-10T10:45:37.148983"
#         }
#     },
#     {
#         "title": "A Mountain Walked: Great Tales of the Cthulhu Mythos",
#         "covers": [
#             8747587,
#             8763386
#         ],
#         "key": "/works/OL20071249W",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2755616A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7617317A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7617318A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL6565372A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL6868205A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL220396A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7617319A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL534271A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL397402A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1295287A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7479035A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL3007139A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL29758A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2827567A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL3745857A"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "latest_revision": 3,
#         "revision": 3,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2019-07-28T06:53:44.183890"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-01-03T18:41:30.769952"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Fearie Tales [signed traycased edition]",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL220396A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL25453A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7206029A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL10337083A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL220575A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL6815968A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7503550A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL24098A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL382982A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7850947A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL10652771A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL636115A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL10652772A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9145261A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL10367814A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7958794A"
#                 }
#             }
#         ],
#         "key": "/works/OL28774667W",
#         "latest_revision": 5,
#         "revision": 5,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-09-15T17:17:00.189016"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2024-01-03T18:29:39.707962"
#         }
#     },
#     {
#         "subjects": [
#             "Individuality",
#             "First day of school",
#             "Schools",
#             "Juvenile fiction",
#             "Pandas",
#             "Fiction",
#             "Animals",
#             "Ability",
#             "Children's fiction",
#             "Pandas, fiction",
#             "First day of school, fiction",
#             "Animals, fiction",
#             "Picture books",
#             "Child and youth fiction"
#         ],
#         "key": "/works/OL17485977W",
#         "title": "Chu's First Day of School",
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "covers": [
#             7673760,
#             8156482,
#             8905822,
#             10330322,
#             12341081
#         ],
#         "latest_revision": 11,
# ...
#         },
#         "title": "Blood Bank",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7583529A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL3027409A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL8225117A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7485067A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL11431059A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1519822A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL8363228A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9365779A"
#                 }
#             }
#         ],
#         "key": "/works/OL31341625W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-06T15:28:20.291884"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "AMER\u0130KAN TANRILARI",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL31967754W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-10T09:03:43.019897"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Interworld",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL29239367W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-10-26T22:17:18.392922"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Neil Gaiman's Troll Bridge",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL28826973W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-09-18T06:36:47.895827"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Gwiezdny py\u0142",
#         "subjects": [
#             "Powie\u015b\u0107 fantastyczna angielska",
#             "T\u0142umaczenia polskie"
#         ],
#         "subject_times": [
#             "1990-"
#         ],
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             13022955
#         ],
#         "key": "/works/OL31212717W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-04T03:27:41.117716"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Bioluminescent",
#         "subjects": [
#             "Fiction, science fiction, general",
#             "Fiction, anthologies (multiple authors)",
#             "solarpunk"
#         ],
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL10394934A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7501009A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL10802936A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "key": "/works/OL29204484W",
#         "description": {
#             "type": "/type/text",
#             "value": "Solarpunk communities that glow when the sun goes down. Witches on distant planets and future pagans building resilient ecotopias. The search for hope in a better world. Evolution and transformation. Exploration and discovery. The pages of this book are filled with wonders both technological and magical. Conflicts lead to resilience and solutions both internal and community-based. Stories span from the terrestrial to the galactic to the inner-depths of memory and imagination.\r\n\r\nFeaturing work by Starhawk, Sarena Ulibarri, Wendy N. Wagner, Neil Gaiman, Justine Norton-Kertson, Yasmin Moita, J.D. Harklock, BrightFlame, Pedro Inguez, and more, twenty-two authors take a variety of different paths as they begin to map out the new and budding lunarpunk genre's terrain. Join them in adventures through glowing utopian worlds where people work together and do their best to build a better for us all. Join the, and explore Lunarpunk."
#         },
#         "latest_revision": 3,
#         "revision": 3,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-10-20T01:01:35.151616"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Creatures of the Night (Second Edition)",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL28828915W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-09-18T07:35:24.977849"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Dym i lustra",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             13332556
#         ],
#         "key": "/works/OL34532681W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-02-23T21:47:38.507991"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Sandman - World'S End",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL34566501W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-02-27T22:26:16.002598"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "El oc\u00e9ano al final del camino",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992934A"
#                 }
#             }
#         ],
#         "covers": [
#             13449791
#         ],
#         "key": "/works/OL34736429W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-03-15T09:27:35.821827"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Coraline",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             13532781
#         ],
#         "key": "/works/OL34784897W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-03-16T22:41:39.618694"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Yoshitaka Amano's HERO Party of One Definitive Edition",
#         "subjects": [
#             "Comics & graphic novels, fantasy",
#             "Fiction, action & adventure"
#         ],
#         "key": "/works/OL28810247W",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2629923A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-09-17T21:34:23.101729"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Untitled Gaiman 1",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL32396752W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-17T08:51:15.242967"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "The Sandman",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2622187A"
#                 }
#             }
#         ],
#         "key": "/works/OL28604758W",
#         "subjects": [
#             "Comics & graphic novels, fantasy"
#         ],
#         "latest_revision": 3,
#         "revision": 3,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-08-10T10:09:40.842380"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Mirrormask",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             13119811
#         ],
#         "key": "/works/OL33138627W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-28T22:25:00.952330"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Coisas Frageis 2",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL28957607W",
#         "covers": [
#             14121133
#         ],
#         "latest_revision": 3,
#         "revision": 3,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-10-08T03:56:04.875914"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-04-18T06:05:07.577012"
#         }
#     }
# ]

# %%
# Convert the results to a DataFrame
gaiman_books = pd.DataFrame(response_json)

gaiman_books.head()
# Out:
#                                          description  \
# 0  American Gods (2001) is a fantasy novel by Bri...
# 1                                                NaN
# 2  Neil Gaiman. Laura Lippman. Lee Child. These a...
# 3                                                NaN
# 4  Video Nasty by Philip Pullman\r\nThe House Of ...
#
#                                                links                title  \
# 0  [{'title': 'Neil Gaiman | Neil's Work | Books ...        American Gods
# 1                                                NaN        American Gods
# 2                                                NaN  A Study in Sherlock
# 3                                                NaN       Midnight Feast
# 4                                                NaN             Scary! 2
#
#                                               covers  \
# 0  [8494659, 10211195, 9327686, 10289649, 1050424...
# 1                                                NaN
# 2                                 [7087161, 8464125]
# 3                                         [10330577]
# 4                                          [8153298]
#
#                                       subject_places  \
# 0  [Chicago, Illinois (United States), Chattanoog...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             subjects  \
# 0  [science fiction, fantasy fiction, Americana, ...
# 1                                                NaN
# 2  [Sherlock Holmes (Fictitious character), Ameri...
# 3  [Children's stories, English, Children's stori...
# 4  [American Horror tales, English Horror tales, ...
#
#                                       subject_people                 key  \
# 0  [Shadow Moon, Mr. Wednesday, Spider, Anansi, L...    /works/OL679360W
# 1                                                NaN  /works/OL37899403W
# 2                  [Sherlock Holmes, John H. Watson]  /works/OL15941727W
# 3                                                NaN  /works/OL21164187W
# 4                                                NaN  /works/OL17852862W
#
#                                              authors  \
# 0  [{'author': {'key': '/authors/OL53305A'}, 'typ...
# 1  [{'author': {'key': '/authors/OL53305A'}, 'typ...
# 2  [{'type': {'key': '/type/author_role'}, 'autho...
# 3  [{'author': {'key': '/authors/OL92953A'}, 'typ...
# 4  [{'author': {'key': '/authors/OL501394A'}, 'ty...
#
#                                             excerpts  ...          location  \
# 0  [{'excerpt': 'Shadow had done three years in p...  ...  /works/OL679360W
# 1                                                NaN  ...               NaN
# 2                                                NaN  ...               NaN
# 3                                                NaN  ...               NaN
# 4                                                NaN  ...               NaN
#
#   latest_revision  revision  \
# 0              72        72
# 1               1         1
# 2              16        16
# 3               8         8
# 4               7         7
#
#                                              created  \
# 0  {'type': '/type/datetime', 'value': '2009-12-0...
# 1  {'type': '/type/datetime', 'value': '2024-02-2...
# 2  {'type': '/type/datetime', 'value': '2011-07-2...
# 3  {'type': '/type/datetime', 'value': '2020-08-0...
# 4  {'type': '/type/datetime', 'value': '2018-03-2...
#
#                                        last_modified subtitle  \
# 0  {'type': '/type/datetime', 'value': '2024-03-1...      NaN
# 1  {'type': '/type/datetime', 'value': '2024-02-2...      NaN
# 2  {'type': '/type/datetime', 'value': '2024-02-1...      NaN
# 3  {'type': '/type/datetime', 'value': '2024-02-1...      NaN
# 4  {'type': '/type/datetime', 'value': '2024-01-3...      NaN
#
#   first_publish_date subject_times dewey_number lc_classifications
# 0                NaN           NaN          NaN                NaN
# 1                NaN           NaN          NaN                NaN
# 2                NaN           NaN          NaN                NaN
# 3                NaN           NaN          NaN                NaN
# 4                NaN           NaN          NaN                NaN
#
# [5 rows x 21 columns]

# %%
gaiman_books.links.iloc[0]
# Out:
# [{'title': "Neil Gaiman | Neil's Work | Books | American Gods",
#   'url': 'http://www.neilgaiman.com/works/Books/American+Gods/ed/102/',
#   'type': {'key': '/type/link'}},
#  {'title': 'American Gods - Wikipedia',
#   'url': 'https://en.wikipedia.org/wiki/American_Gods',
#   'type': {'key': '/type/link'}},
#  {'title': 'publishersweekly.com/978-0-380-97365-1',
#   'url': 'https://www.publishersweekly.com/978-0-380-97365-1',
#   'type': {'key': '/type/link'}},
#  {'title': 'Neil Gaiman, “American Gods: The Tenth Anniversary Edition”',
#   'url': 'https://www.newyorker.com/recommends/listen/american-gods-the-tenth-anniversary-edition',
#   'type': {'key': '/type/link'}},
#  {'title': 'New York Times review',
#   'url': 'http://www.nytimes.com/2001/07/29/books/books-in-brief-fiction-poetry-319619.html',
#   'type': {'key': '/type/link'}}]

# %%
# Convert the results to a DataFrame, normalizing the JSON
json_nested = pd.json_normalize(response_json)

json_nested
# Out:
#                                            description  \
# 0    American Gods (2001) is a fantasy novel by Bri...
# 1                                                  NaN
# 2    Neil Gaiman. Laura Lippman. Lee Child. These a...
# 3                                                  NaN
# 4    Video Nasty by Philip Pullman\r\nThe House Of ...
# ..                                                 ...
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
#
#                                                  links  \
# 0    [{'title': 'Neil Gaiman | Neil's Work | Books ...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
#
#                                                  title  \
# 0                                        American Gods
# 1                                        American Gods
# 2                                  A Study in Sherlock
# 3                                       Midnight Feast
# 4                                             Scary! 2
# ..                                                 ...
# 145  Yoshitaka Amano's HERO Party of One Definitive...
# 146                                  Untitled Gaiman 1
# 147                                        The Sandman
# 148                                         Mirrormask
# 149                                   Coisas Frageis 2
#
#                                                 covers  \
# 0    [8494659, 10211195, 9327686, 10289649, 1050424...
# 1                                                  NaN
# 2                                   [7087161, 8464125]
# 3                                           [10330577]
# 4                                            [8153298]
# ..                                                 ...
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                         [13119811]
# 149                                         [14121133]
#
#                                         subject_places  \
# 0    [Chicago, Illinois (United States), Chattanoog...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
#
#                                               subjects  \
# 0    [science fiction, fantasy fiction, Americana, ...
# 1                                                  NaN
# 2    [Sherlock Holmes (Fictitious character), Ameri...
# 3    [Children's stories, English, Children's stori...
# 4    [American Horror tales, English Horror tales, ...
# ..                                                 ...
# 145  [Comics & graphic novels, fantasy, Fiction, ac...
# 146                                                NaN
# 147                 [Comics & graphic novels, fantasy]
# 148                                                NaN
# 149                                                NaN
#
#                                         subject_people                 key  \
# 0    [Shadow Moon, Mr. Wednesday, Spider, Anansi, L...    /works/OL679360W
# 1                                                  NaN  /works/OL37899403W
# 2                    [Sherlock Holmes, John H. Watson]  /works/OL15941727W
# 3                                                  NaN  /works/OL21164187W
# 4                                                  NaN  /works/OL17852862W
# ..                                                 ...                 ...
# 145                                                NaN  /works/OL28810247W
# 146                                                NaN  /works/OL32396752W
# 147                                                NaN  /works/OL28604758W
# 148                                                NaN  /works/OL33138627W
# 149                                                NaN  /works/OL28957607W
#
#                                                authors  \
# 0    [{'author': {'key': '/authors/OL53305A'}, 'typ...
# 1    [{'author': {'key': '/authors/OL53305A'}, 'typ...
# 2    [{'type': {'key': '/type/author_role'}, 'autho...
# 3    [{'author': {'key': '/authors/OL92953A'}, 'typ...
# 4    [{'author': {'key': '/authors/OL501394A'}, 'ty...
# ..                                                 ...
# 145  [{'type': {'key': '/type/author_role'}, 'autho...
# 146  [{'type': {'key': '/type/author_role'}, 'autho...
# 147  [{'type': {'key': '/type/author_role'}, 'autho...
# 148  [{'type': {'key': '/type/author_role'}, 'autho...
# 149  [{'type': {'key': '/type/author_role'}, 'autho...
#
#                                               excerpts  ...  \
# 0    [{'excerpt': 'Shadow had done three years in p...  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 145                                                NaN  ...
# 146                                                NaN  ...
# 147                                                NaN  ...
# 148                                                NaN  ...
# 149                                                NaN  ...
#
#                   created.value  last_modified.type  \
# 0    2009-12-09T01:11:34.644230      /type/datetime
# 1    2024-02-24T19:15:24.775582      /type/datetime
# 2    2011-07-26T20:28:27.998315      /type/datetime
# 3    2020-08-08T14:56:34.248414      /type/datetime
# 4    2018-03-27T07:23:41.980872      /type/datetime
# ..                          ...                 ...
# 145  2022-09-17T21:34:23.101729      /type/datetime
# 146  2022-12-17T08:51:15.242967      /type/datetime
# 147  2022-08-10T10:09:40.842380      /type/datetime
# 148  2022-12-28T22:25:00.952330      /type/datetime
# 149  2022-10-08T03:56:04.875914      /type/datetime
#
#             last_modified.value subtitle first_publish_date subject_times  \
# 0    2024-03-19T17:37:10.245974      NaN                NaN           NaN
# 1    2024-02-24T19:15:24.775582      NaN                NaN           NaN
# 2    2024-02-18T17:33:32.214622      NaN                NaN           NaN
# 3    2024-02-10T11:28:13.947022      NaN                NaN           NaN
# 4    2024-01-31T20:58:47.726642      NaN                NaN           NaN
# ..                          ...      ...                ...           ...
# 145  2023-03-19T17:38:48.118928      NaN                NaN           NaN
# 146  2023-03-19T17:38:48.118928      NaN                NaN           NaN
# 147  2023-03-19T17:38:48.118928      NaN                NaN           NaN
# 148  2023-03-19T17:38:48.118928      NaN                NaN           NaN
# 149  2023-04-18T06:05:07.577012      NaN                NaN           NaN
#
#     dewey_number description.type description.value lc_classifications
# 0            NaN              NaN               NaN                NaN
# 1            NaN              NaN               NaN                NaN
# 2            NaN              NaN               NaN                NaN
# 3            NaN              NaN               NaN                NaN
# 4            NaN              NaN               NaN                NaN
# ..           ...              ...               ...                ...
# 145          NaN              NaN               NaN                NaN
# 146          NaN              NaN               NaN                NaN
# 147          NaN              NaN               NaN                NaN
# 148          NaN              NaN               NaN                NaN
# 149          NaN              NaN               NaN                NaN
#
# [150 rows x 25 columns]

# %%
# Export to CSV
json_nested.to_csv('gamin_books.csv', index=False)
