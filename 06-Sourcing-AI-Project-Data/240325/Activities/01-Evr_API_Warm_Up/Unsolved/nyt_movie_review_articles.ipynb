# %%
# Import dependencies
import requests
import json
import pandas as pd
from dotenv import load_dotenv
import os
import time

# Load environment variables and New York Times API key
load_dotenv()
api_key = os.getenv("NYT_API_KEY")

# New York Times Article API URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for movie reviews published between a begin and end date
# Select reviews published in July 2023
begin_date = "20230701"
end_date = "20230731"

# Build URL
requestUrl = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date={begin_date}&end_date=20230731&fl=headline%2Cweb_url%2Csnippet%2Csource%2Ckeywords%2Cpub_date%2Cbyline%2Cword_count&fq=section_name%3A%22Movies%22%20AND%20type_of_material%3A%22Review%22&sort=newest&api-key={api_key}"

# %%
# Get the response
response = requests.get(requestUrl)
response
# Out:
# <Response [200]>

# %%
reviews['response']['docs']
# Out:
# [{'web_url': 'https://www.nytimes.com/2023/07/27/movies/war-pony-review.html',
#   'snippet': 'Riley Keough and Gina Gammell’s stellar debut, starring many first-time actors, takes a deadpan look at a Lakota-Sioux reservation in South Dakota.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘War Pony’ Review: The Sad Absurdities of Reservation Life',
#    'kicker': 'Critic’s Pick',
#    'content_kicker': None,
#    'print_headline': 'The Endless Absurdities  Of Life on a Reservation ',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'},
#    {'name': 'persons', 'value': 'Keough, Riley', 'rank': 2, 'major': 'N'},
#    {'name': 'persons', 'value': 'Gammell, Gina', 'rank': 3, 'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'War Pony (Movie)',
#     'rank': 4,
#     'major': 'N'}],
#   'pub_date': '2023-07-27T18:26:30+0000',
#   'byline': {'original': 'By Amy Nicholson',
#    'person': [{'firstname': 'Amy',
#      'middlename': None,
#      'lastname': 'Nicholson',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 504},
#  {'web_url': 'https://www.nytimes.com/2023/07/27/movies/the-unknown-country-review.html',
#   'snippet': 'Lily Gladstone’s achingly measured performance braided with the actual stories from nonprofessional actors makes Morrisa Maltz’s film a memorable road trip.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘The Unknown Country’ Review: A Granddaughter’s Road Trip',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'The Unknown Country',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'},
#    {'name': 'persons', 'value': 'Gladstone, Lily', 'rank': 2, 'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'The Unknown Country (Movie)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Maltz, Morrisa', 'rank': 4, 'major': 'N'}],
#   'pub_date': '2023-07-27T17:58:33+0000',
#   'byline': {'original': 'By Lisa Kennedy',
#    'person': [{'firstname': 'Lisa',
#      'middlename': None,
#      'lastname': 'Kennedy',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 282},
#  {'web_url': 'https://www.nytimes.com/2023/07/27/movies/kokomo-city-review.html',
#   'snippet': 'The director D. Smith’s new documentary follows four Black transgender women, who talk about how they got into sex work.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘Kokomo City’ Review: Dispatches From the Down Low',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Intimate Stories of Tough Lives',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Documentary Films and Programs',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Smith, D (Filmmaker)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'Kokomo City (Movie)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Transgender', 'rank': 4, 'major': 'N'},
#    {'name': 'subject', 'value': 'Black People', 'rank': 5, 'major': 'N'},
#    {'name': 'subject', 'value': 'Blacks', 'rank': 6, 'major': 'N'},
#    {'name': 'subject', 'value': 'Prostitution', 'rank': 7, 'major': 'N'}],
#   'pub_date': '2023-07-27T17:00:45+0000',
#   'byline': {'original': 'By Teo Bugbee',
#    'person': [{'firstname': 'Teo',
#      'middlename': None,
#      'lastname': 'Bugbee',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 433},
#  {'web_url': 'https://www.nytimes.com/2023/07/27/movies/bobi-wine-the-peoples-president-review.html',
#   'snippet': 'Uganda has been under authoritarian rule for decades. Wine has doggedly challenged its leader, and this documentary shows the price he’s paid.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘Bobi Wine: The People’s President’ Review: A Pop Star Turns Politician',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Bobi Wine:  The People’s President',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Documentary Films and Programs',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Kyagulanyi Ssentamu, Robert (Bobi Wine)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Uganda', 'rank': 3, 'major': 'N'},
#    {'name': 'creative_works',
#     'value': "Bobi Wine: The People's President (Movie)",
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Bwayo, Moses', 'rank': 5, 'major': 'N'},
#    {'name': 'persons',
#     'value': 'Sharp, Christopher (Film Director)',
#     'rank': 6,
#     'major': 'N'}],
#   'pub_date': '2023-07-27T11:00:20+0000',
#   'byline': {'original': 'By Glenn Kenny',
#    'person': [{'firstname': 'Glenn',
#      'middlename': None,
#      'lastname': 'Kenny',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 307},
#  {'web_url': 'https://www.nytimes.com/2023/07/27/movies/el-agua-review.html',
#   'snippet': 'This film from Elena López Riera follows what happens when floods drench a village in southeastern Spain.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘El Agua’ Review: After the Flood, the Legends',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'El Agua',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'El Agua (Movie)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Lopez Riera, Elena',
#     'rank': 3,
#     'major': 'N'}],
#   'pub_date': '2023-07-27T11:00:18+0000',
#   'byline': {'original': 'By Devika Girish',
#    'person': [{'firstname': 'Devika',
#      'middlename': None,
#      'lastname': 'Girish',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 293},
#  {'web_url': 'https://www.nytimes.com/2023/07/27/movies/happiness-for-beginners-review.html',
#   'snippet': 'Ellie Kemper and Luke Grimes star in “Happiness for Beginners,” an outdoorsy rom-com that’s inoffensive to a fault.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘Happiness for Beginners’ Review: Live, Laugh, Hike',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Happiness  For Beginners',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'},
#    {'name': 'persons', 'value': 'Kemper, Ellie', 'rank': 2, 'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'Happiness for Beginners (Movie)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Center, Katherine (1972- )',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'Happiness for Beginners: A Novel (Book)',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Grimes, Luke (1984- )',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Wight, Vicky (Film Director)',
#     'rank': 7,
#     'major': 'N'}],
#   'pub_date': '2023-07-27T11:00:17+0000',
#   'byline': {'original': 'By Claire Shaffer',
#    'person': [{'firstname': 'Claire',
#      'middlename': None,
#      'lastname': 'Shaffer',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 256},
#  {'web_url': 'https://www.nytimes.com/2023/07/27/movies/zoey-102-review.html',
#   'snippet': '15 Years after her Nickelodeon show, “Zoey 101,” ended, Jamie Lynn Spears returns in a serviceable movie sequel.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘Zoey 102’ Review: Grown Up, Washed Up',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Zoey 102',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'},
#    {'name': 'persons', 'value': 'Spears, Jamie Lynn', 'rank': 2, 'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'Zoey 102 (Movie)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Hower, Nancy', 'rank': 4, 'major': 'N'},
#    {'name': 'persons',
#     'value': 'Schneider, Dan (1966- )',
#     'rank': 5,
#     'major': 'N'}],
#   'pub_date': '2023-07-27T11:00:15+0000',
#   'byline': {'original': 'By Brandon Yu',
#    'person': [{'firstname': 'Brandon',
#      'middlename': None,
#      'lastname': 'Yu',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 276},
#  {'web_url': 'https://www.nytimes.com/2023/07/27/movies/the-beanie-bubble-review.html',
#   'snippet': 'This dramatic comedy about Beanie Babies, starring Zach Galifianakis, Elizabeth Banks and Sarah Snook, arrives at the tail end of a summer of corporate biopics.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘The Beanie Bubble’ Review: Caught in a Fad Romance',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Crazy Capitalism: The Beanie Baby Story',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Apple TV Plus',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Banks, Elizabeth', 'rank': 3, 'major': 'N'},
#    {'name': 'persons', 'value': 'Galifianakis, Zach', 'rank': 4, 'major': 'N'},
#    {'name': 'persons', 'value': 'Snook, Sarah', 'rank': 5, 'major': 'N'},
#    {'name': 'persons',
#     'value': 'Viswanathan, Geraldine',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'The Beanie Bubble (Movie)',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Gore, Kristin C', 'rank': 8, 'major': 'N'},
#    {'name': 'persons', 'value': 'Kulash, Damian', 'rank': 9, 'major': 'N'}],
#   'pub_date': '2023-07-27T11:00:11+0000',
#   'byline': {'original': 'By Calum Marsh',
#    'person': [{'firstname': 'Calum',
#      'middlename': None,
#      'lastname': 'Marsh',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 587},
#  {'web_url': 'https://www.nytimes.com/2023/07/27/movies/north-circular-review.html',
#   'snippet': 'In this black-and-white documentary by Luke McManus, the camera finds stories and songs near a road north of the city’s center.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘North Circular’ Review: A Musical Tour Through Dublin',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'North Circular',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Documentary Films and Programs',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Folk Music', 'rank': 2, 'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Dublin (Ireland)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'North Circular (Movie)',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'McManus, Luke (Film Director)',
#     'rank': 5,
#     'major': 'N'}],
#   'pub_date': '2023-07-27T11:00:11+0000',
#   'byline': {'original': 'By Ben Kenigsberg',
#    'person': [{'firstname': 'Ben',
#      'middlename': None,
#      'lastname': 'Kenigsberg',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 315},
#  {'web_url': 'https://www.nytimes.com/2023/07/27/movies/the-beasts-review.html',
#   'snippet': 'Class tensions and masculine power games abound in this engrossing rural thriller from Spain.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘The Beasts’ Review: Bad Neighbors',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'The Beasts',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'},
#    {'name': 'persons', 'value': 'Sorogoyen, Rodrigo', 'rank': 2, 'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'The Beasts (Movie)',
#     'rank': 3,
#     'major': 'N'}],
#   'pub_date': '2023-07-27T11:00:10+0000',
#   'byline': {'original': 'By Beatrice Loayza',
#    'person': [{'firstname': 'Beatrice',
#      'middlename': None,
#      'lastname': 'Loayza',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'word_count': 301}]

# %%
# Retrieve reviews
reviews = response.json()

# Print results in JSON format
print(json.dumps(reviews, indent=4))
# Out:
# {
#     "status": "OK",
#     "copyright": "Copyright (c) 2024 The New York Times Company. All Rights Reserved.",
#     "response": {
#         "docs": [
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/war-pony-review.html",
#                 "snippet": "Riley Keough and Gina Gammell\u2019s stellar debut, starring many first-time actors, takes a deadpan look at a Lakota-Sioux reservation in South Dakota.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018War Pony\u2019 Review: The Sad Absurdities of Reservation Life",
#                     "kicker": "Critic\u2019s Pick",
#                     "content_kicker": null,
#                     "print_headline": "The Endless Absurdities  Of Life on a Reservation ",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Keough, Riley",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Gammell, Gina",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "War Pony (Movie)",
#                         "rank": 4,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T18:26:30+0000",
#                 "byline": {
#                     "original": "By Amy Nicholson",
#                     "person": [
#                         {
#                             "firstname": "Amy",
#                             "middlename": null,
#                             "lastname": "Nicholson",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 504
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/the-unknown-country-review.html",
#                 "snippet": "Lily Gladstone\u2019s achingly measured performance braided with the actual stories from nonprofessional actors makes Morrisa Maltz\u2019s film a memorable road trip.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018The Unknown Country\u2019 Review: A Granddaughter\u2019s Road Trip",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "The Unknown Country",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Gladstone, Lily",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "The Unknown Country (Movie)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Maltz, Morrisa",
#                         "rank": 4,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T17:58:33+0000",
#                 "byline": {
#                     "original": "By Lisa Kennedy",
#                     "person": [
#                         {
#                             "firstname": "Lisa",
#                             "middlename": null,
#                             "lastname": "Kennedy",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 282
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/kokomo-city-review.html",
#                 "snippet": "The director D. Smith\u2019s new documentary follows four Black transgender women, who talk about how they got into sex work.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Kokomo City\u2019 Review: Dispatches From the Down Low",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Intimate Stories of Tough Lives",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Documentary Films and Programs",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Smith, D (Filmmaker)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Kokomo City (Movie)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Transgender",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Black People",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Blacks",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Prostitution",
#                         "rank": 7,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T17:00:45+0000",
#                 "byline": {
#                     "original": "By Teo Bugbee",
#                     "person": [
#                         {
#                             "firstname": "Teo",
#                             "middlename": null,
#                             "lastname": "Bugbee",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 433
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/bobi-wine-the-peoples-president-review.html",
#                 "snippet": "Uganda has been under authoritarian rule for decades. Wine has doggedly challenged its leader, and this documentary shows the price he\u2019s paid.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Bobi Wine: The People\u2019s President\u2019 Review: A Pop Star Turns Politician",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Bobi Wine:  The People\u2019s President",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Documentary Films and Programs",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Kyagulanyi Ssentamu, Robert (Bobi Wine)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Uganda",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Bobi Wine: The People's President (Movie)",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Bwayo, Moses",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Sharp, Christopher (Film Director)",
#                         "rank": 6,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T11:00:20+0000",
#                 "byline": {
#                     "original": "By Glenn Kenny",
#                     "person": [
#                         {
#                             "firstname": "Glenn",
#                             "middlename": null,
#                             "lastname": "Kenny",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 307
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/el-agua-review.html",
#                 "snippet": "This film from Elena L\u00f3pez Riera follows what happens when floods drench a village in southeastern Spain.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018El Agua\u2019 Review: After the Flood, the Legends",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "El Agua",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "El Agua (Movie)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Lopez Riera, Elena",
#                         "rank": 3,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T11:00:18+0000",
#                 "byline": {
#                     "original": "By Devika Girish",
#                     "person": [
#                         {
#                             "firstname": "Devika",
#                             "middlename": null,
#                             "lastname": "Girish",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 293
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/happiness-for-beginners-review.html",
#                 "snippet": "Ellie Kemper and Luke Grimes star in \u201cHappiness for Beginners,\u201d an outdoorsy rom-com that\u2019s inoffensive to a fault.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Happiness for Beginners\u2019 Review: Live, Laugh, Hike",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Happiness  For Beginners",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Kemper, Ellie",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Happiness for Beginners (Movie)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Center, Katherine (1972- )",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Happiness for Beginners: A Novel (Book)",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Grimes, Luke (1984- )",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Wight, Vicky (Film Director)",
#                         "rank": 7,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T11:00:17+0000",
#                 "byline": {
#                     "original": "By Claire Shaffer",
#                     "person": [
#                         {
#                             "firstname": "Claire",
#                             "middlename": null,
#                             "lastname": "Shaffer",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 256
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/zoey-102-review.html",
#                 "snippet": "15 Years after her Nickelodeon show, \u201cZoey 101,\u201d ended, Jamie Lynn Spears returns in a serviceable movie sequel.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Zoey 102\u2019 Review: Grown Up, Washed Up",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Zoey 102",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Spears, Jamie Lynn",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Zoey 102 (Movie)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Hower, Nancy",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Schneider, Dan (1966- )",
#                         "rank": 5,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T11:00:15+0000",
#                 "byline": {
#                     "original": "By Brandon Yu",
#                     "person": [
#                         {
#                             "firstname": "Brandon",
#                             "middlename": null,
#                             "lastname": "Yu",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 276
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/the-beanie-bubble-review.html",
#                 "snippet": "This dramatic comedy about Beanie Babies, starring Zach Galifianakis, Elizabeth Banks and Sarah Snook, arrives at the tail end of a summer of corporate biopics.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018The Beanie Bubble\u2019 Review: Caught in a Fad Romance",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Crazy Capitalism: The Beanie Baby Story",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Apple TV Plus",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Banks, Elizabeth",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Galifianakis, Zach",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Snook, Sarah",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Viswanathan, Geraldine",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "The Beanie Bubble (Movie)",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Gore, Kristin C",
#                         "rank": 8,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Kulash, Damian",
#                         "rank": 9,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T11:00:11+0000",
#                 "byline": {
#                     "original": "By Calum Marsh",
#                     "person": [
#                         {
#                             "firstname": "Calum",
#                             "middlename": null,
#                             "lastname": "Marsh",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 587
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/north-circular-review.html",
#                 "snippet": "In this black-and-white documentary by Luke McManus, the camera finds stories and songs near a road north of the city\u2019s center.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018North Circular\u2019 Review: A Musical Tour Through Dublin",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "North Circular",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Documentary Films and Programs",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Folk Music",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Dublin (Ireland)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "North Circular (Movie)",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "McManus, Luke (Film Director)",
#                         "rank": 5,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T11:00:11+0000",
#                 "byline": {
#                     "original": "By Ben Kenigsberg",
#                     "person": [
#                         {
#                             "firstname": "Ben",
#                             "middlename": null,
#                             "lastname": "Kenigsberg",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 315
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/07/27/movies/the-beasts-review.html",
#                 "snippet": "Class tensions and masculine power games abound in this engrossing rural thriller from Spain.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018The Beasts\u2019 Review: Bad Neighbors",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "The Beasts",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Sorogoyen, Rodrigo",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "The Beasts (Movie)",
#                         "rank": 3,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-07-27T11:00:10+0000",
#                 "byline": {
#                     "original": "By Beatrice Loayza",
#                     "person": [
#                         {
#                             "firstname": "Beatrice",
#                             "middlename": null,
#                             "lastname": "Loayza",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 301
#             }
#         ],
#         "meta": {
#             "hits": 52,
#             "offset": 0,
#             "time": 15
#         }
#     }
# }

# %%
# Convert results list to JSON normalized Pandas DataFrame
data = pd.json_normalize(reviews['response']['docs'])
data
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/07/27/movies/war-...
# 1  https://www.nytimes.com/2023/07/27/movies/the-...
# 2  https://www.nytimes.com/2023/07/27/movies/koko...
# 3  https://www.nytimes.com/2023/07/27/movies/bobi...
# 4  https://www.nytimes.com/2023/07/27/movies/el-a...
# 5  https://www.nytimes.com/2023/07/27/movies/happ...
# 6  https://www.nytimes.com/2023/07/27/movies/zoey...
# 7  https://www.nytimes.com/2023/07/27/movies/the-...
# 8  https://www.nytimes.com/2023/07/27/movies/nort...
# 9  https://www.nytimes.com/2023/07/27/movies/the-...
#
#                                              snippet              source  \
# 0  Riley Keough and Gina Gammell’s stellar debut,...  The New York Times
# 1  Lily Gladstone’s achingly measured performance...  The New York Times
# 2  The director D. Smith’s new documentary follow...  The New York Times
# 3  Uganda has been under authoritarian rule for d...  The New York Times
# 4  This film from Elena López Riera follows what ...  The New York Times
# 5  Ellie Kemper and Luke Grimes star in “Happines...  The New York Times
# 6  15 Years after her Nickelodeon show, “Zoey 101...  The New York Times
# 7  This dramatic comedy about Beanie Babies, star...  The New York Times
# 8  In this black-and-white documentary by Luke Mc...  The New York Times
# 9  Class tensions and masculine power games aboun...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Documentary Fil...
# 3  [{'name': 'subject', 'value': 'Documentary Fil...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 5  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 6  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 7  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 8  [{'name': 'subject', 'value': 'Documentary Fil...
# 9  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-07-27T18:26:30+0000         504
# 1  2023-07-27T17:58:33+0000         282
# 2  2023-07-27T17:00:45+0000         433
# 3  2023-07-27T11:00:20+0000         307
# 4  2023-07-27T11:00:18+0000         293
# 5  2023-07-27T11:00:17+0000         256
# 6  2023-07-27T11:00:15+0000         276
# 7  2023-07-27T11:00:11+0000         587
# 8  2023-07-27T11:00:11+0000         315
# 9  2023-07-27T11:00:10+0000         301
#
#                                        headline.main headline.kicker  \
# 0  ‘War Pony’ Review: The Sad Absurdities of Rese...   Critic’s Pick
# 1  ‘The Unknown Country’ Review: A Granddaughter’...            None
# 2  ‘Kokomo City’ Review: Dispatches From the Down...            None
# 3  ‘Bobi Wine: The People’s President’ Review: A ...            None
# 4     ‘El Agua’ Review: After the Flood, the Legends            None
# 5  ‘Happiness for Beginners’ Review: Live, Laugh,...            None
# 6             ‘Zoey 102’ Review: Grown Up, Washed Up            None
# 7  ‘The Beanie Bubble’ Review: Caught in a Fad Ro...            None
# 8  ‘North Circular’ Review: A Musical Tour Throug...            None
# 9                 ‘The Beasts’ Review: Bad Neighbors            None
#
#   headline.content_kicker                            headline.print_headline  \
# 0                    None  The Endless Absurdities  Of Life on a Reservat...
# 1                    None                                The Unknown Country
# 2                    None                    Intimate Stories of Tough Lives
# 3                    None                 Bobi Wine:  The People’s President
# 4                    None                                            El Agua
# 5                    None                           Happiness  For Beginners
# 6                    None                                           Zoey 102
# 7                    None            Crazy Capitalism: The Beanie Baby Story
# 8                    None                                     North Circular
# 9                    None                                         The Beasts
#
#   headline.name headline.seo headline.sub     byline.original  \
# 0          None         None         None    By Amy Nicholson
# 1          None         None         None     By Lisa Kennedy
# 2          None         None         None       By Teo Bugbee
# 3          None         None         None      By Glenn Kenny
# 4          None         None         None    By Devika Girish
# 5          None         None         None   By Claire Shaffer
# 6          None         None         None       By Brandon Yu
# 7          None         None         None      By Calum Marsh
# 8          None         None         None   By Ben Kenigsberg
# 9          None         None         None  By Beatrice Loayza
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 1  [{'firstname': 'Lisa', 'middlename': None, 'la...                None
# 2  [{'firstname': 'Teo', 'middlename': None, 'las...                None
# 3  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Devika', 'middlename': None, '...                None
# 5  [{'firstname': 'Claire', 'middlename': None, '...                None
# 6  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 7  [{'firstname': 'Calum', 'middlename': None, 'l...                None
# 8  [{'firstname': 'Ben', 'middlename': None, 'las...                None
# 9  [{'firstname': 'Beatrice', 'middlename': None,...                None

# %%
data.columns
# Out:
# Index(['web_url', 'snippet', 'source', 'keywords', 'pub_date', 'word_count',
#        'headline.main', 'headline.kicker', 'headline.content_kicker',
#        'headline.print_headline', 'headline.name', 'headline.seo',
#        'headline.sub', 'byline.original', 'byline.person',
#        'byline.organization'],
#       dtype='object')

# %%
# Get the unique writer bylines as a Series
writers = data['byline.original']
writers
# Out:
# 0      By Amy Nicholson
# 1       By Lisa Kennedy
# 2         By Teo Bugbee
# 3        By Glenn Kenny
# 4      By Devika Girish
# 5     By Claire Shaffer
# 6         By Brandon Yu
# 7        By Calum Marsh
# 8     By Ben Kenigsberg
# 9    By Beatrice Loayza
# Name: byline.original, dtype: object

# %%
# Convert the writers Series to a list
list_writers = writers.to_list()

list(writers)
# Out:
# ['By Amy Nicholson',
#  'By Lisa Kennedy',
#  'By Teo Bugbee',
#  'By Glenn Kenny',
#  'By Devika Girish',
#  'By Claire Shaffer',
#  'By Brandon Yu',
#  'By Calum Marsh',
#  'By Ben Kenigsberg',
#  'By Beatrice Loayza']

# %%
import random
random.randint(12, 20)
# Out:
# 13

# %%
data = pd.json_normalize(reviews['response']['docs'])

# %%
# Use the writers list to find the most recent articles by the same writer

# Empty list for results
results_list = []

# loop through the writers_list
for writer in list_writers:
    # Set up the query
    url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?byline={writer}sort=newest&api-key={api_key}&fl={field_list}"
    
    # Get the results
    result = requests.get(url).json()
    # results_list.append(result)

    
    # Add a 12 second interval between queries to stay within API query limits
    time.sleep(12) # 5 times per minute

    # Use a try-except clause to collect results
    try: 
        # Loop through the "docs"
        for each_doc in result['response']['docs']:
            data = {
                'web_url'  : each_doc['web_url'],
                "snippet"  : each_doc['snippet'],
                "headline" : each_doc['headline']['main'],
                'byline'   : each_doc['byline']['original']
            }

            results_list.append(data)

            # Save byline.original, headline.main, snippet,
            # and web_url
        print(writer)
    except:
        print("No articles found")
# Out:
# By Amy Nicholson
# By Lisa Kennedy
# By Teo Bugbee
# By Glenn Kenny
# By Devika Girish
# By Claire Shaffer
# By Brandon Yu
# By Calum Marsh
# By Ben Kenigsberg
# By Beatrice Loayza

# %%
# Convert the results to a Pandas DataFrame
pd.DataFrame(results_list)
# Out:
#                                               web_url  \
# 0   https://www.nytimes.com/2024/03/25/nyregion/su...
# 1   https://www.nytimes.com/2024/03/25/business/fl...
# 2   https://www.nytimes.com/2024/03/25/science/bir...
# 3   https://www.nytimes.com/2024/03/25/style/succe...
# 4   https://www.nytimes.com/2024/03/25/world/middl...
# ..                                                ...
# 95  https://www.nytimes.com/2024/03/25/opinion/tru...
# 96  https://www.nytimes.com/2024/03/25/us/politics...
# 97  https://www.nytimes.com/2024/03/25/us/politics...
# 98  https://www.nytimes.com/2024/03/25/well/fda-co...
# 99  https://www.nytimes.com/2024/03/25/arts/music/...
#
#                                               snippet  \
# 0   The attack at 125th Street in East Harlem was ...
# 1   A new Florida law also requires apps like TikT...
# 2   U.S. regulators confirmed that sick cattle in ...
# 3   Ilia Malinin, an American teenager, won the me...
# 4   The U.S. decision not to vote on the resolutio...
# ..                                                ...
# 95  Republicans seem determined to destroy the Aff...
# 96  The use of an expletive from a Trump campaign ...
# 97  “He’s outspoken. As far as I know, he’s not cr...
# 98  Pemgarda, available in the coming weeks, is in...
# 99  In response to questions about Mr. Combs’s res...
#
#                                              headline  \
# 0   Person Killed by Train After Being Pushed Onto...
# 1   DeSantis Signs Social Media Bill Barring Accou...
# 2                      Bird Flu Spreads to Dairy Cows
# 3                                 ‘Succession’ on Ice
# 4   U.N. Security Council Calls for Immediate Ceas...
# ..                                                ...
# 95                Obamacare Is in Grave Danger, Again
# 96  Trump team takes sparring with Biden into vulg...
# 97                        Who Are the RFK Jr. Voters?
# 98  F.D.A. Authorizes New Drug to Protect High-Ris...
# 99  Federal Agents Raid Homes Tied to Sean Combs i...
#
#                                                byline
# 0                                 By Christopher Maag
# 1                                   By Natasha Singer
# 2                                     By Emily Anthes
# 3                               By Misty White Sidell
# 4   By Farnaz Fassihi, Aaron Boxerman and Thomas F...
# ..                                                ...
# 95                                    By Paul Krugman
# 96                                    By Michael Gold
# 97                                    By Katie Glueck
# 98                                       By Dani Blum
# 99  By Ben Sisario, Julia Jacobs and William K. Ra...
#
# [100 rows x 4 columns]
