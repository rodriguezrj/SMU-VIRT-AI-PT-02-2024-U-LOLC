# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
# Import the data
df = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m14/datasets/crowdfunding-data.csv")
df.head()
# Out:
#      goal  pledged  backers_count  country  staff_pick  spotlight  category  \
# 0     100        0              0        3           0          0         0
# 1    1400    14560            158        0           0          1         1
# 2  108400   142523           1425        4           0          0         2
# 3    4200     2477             24        0           0          0         1
# 4    7600     5265             53        0           0          0         3
#
#    days_active  outcome
# 0           17        0
# 1           27        1
# 2           20        1
# 3           40        0
# 4            4        0

# %%
# Create a column "pledged_per_backer"
df['pledged_per_backer'] = df['pledged'] / df['backers_count']
df
# Out:
#         goal  pledged  backers_count  country  staff_pick  spotlight  \
# 0        100        0              0        3           0          0
# 1       1400    14560            158        0           0          1
# 2     108400   142523           1425        4           0          0
# 3       4200     2477             24        0           0          0
# 4       7600     5265             53        0           0          0
# ...      ...      ...            ...      ...         ...        ...
# 1124   17130    15894            847        2           0          0
# 1125   97329    80937            862        6           0          0
# 1126   53597    40388             58        0           0          0
# 1127   71588    18102            274        0           0          0
# 1128   88382    28181            113        2           0          0
#
#       category  days_active  outcome  pledged_per_backer
# 0            0           17        0                 NaN
# 1            1           27        1           92.151899
# 2            2           20        1          100.016140
# 3            1           40        0          103.208333
# 4            3            4        0           99.339623
# ...        ...          ...      ...                 ...
# 1124         5            6        0           18.765053
# 1125         3           29        0           93.894432
# 1126         9           46        0          696.344828
# 1127         2           43        0           66.065693
# 1128         2           41        0          249.389381
#
# [1129 rows x 10 columns]

# %%
# Fill the missing values with zeros
df['pledged_per_backer'] = df['pledged_per_backer'].fillna(0)
df.head()
# Out:
#      goal  pledged  backers_count  country  staff_pick  spotlight  category  \
# 0     100        0              0        3           0          0         0
# 1    1400    14560            158        0           0          1         1
# 2  108400   142523           1425        4           0          0         2
# 3    4200     2477             24        0           0          0         1
# 4    7600     5265             53        0           0          0         3
#
#    days_active  outcome  pledged_per_backer
# 0           17        0            0.000000
# 1           27        1           92.151899
# 2           20        1          100.016140
# 3           40        0          103.208333
# 4            4        0           99.339623

# %%
# Create a backers_per_day column
df['backers_per_day'] = df['backers_count'] / df['days_active']
df
# Out:
#         goal  pledged  backers_count  country  staff_pick  spotlight  \
# 0        100        0              0        3           0          0
# 1       1400    14560            158        0           0          1
# 2     108400   142523           1425        4           0          0
# 3       4200     2477             24        0           0          0
# 4       7600     5265             53        0           0          0
# ...      ...      ...            ...      ...         ...        ...
# 1124   17130    15894            847        2           0          0
# 1125   97329    80937            862        6           0          0
# 1126   53597    40388             58        0           0          0
# 1127   71588    18102            274        0           0          0
# 1128   88382    28181            113        2           0          0
#
#       category  days_active  outcome  pledged_per_backer  backers_per_day
# 0            0           17        0            0.000000         0.000000
# 1            1           27        1           92.151899         5.851852
# 2            2           20        1          100.016140        71.250000
# 3            1           40        0          103.208333         0.600000
# 4            3            4        0           99.339623        13.250000
# ...        ...          ...      ...                 ...              ...
# 1124         5            6        0           18.765053       141.166667
# 1125         3           29        0           93.894432        29.724138
# 1126         9           46        0          696.344828         1.260870
# 1127         2           43        0           66.065693         6.372093
# 1128         2           41        0          249.389381         2.756098
#
# [1129 rows x 11 columns]

# %%
import math
float(math.inf)
# Out:
# inf

# %%
# Create a days_to_goal column

# Create a function to apply
def days_to_goal(row):
    amount_remaining = row['goal']-row['pledged']
    if row['pledged'] > row['goal']:
        return 0
    pledged_per_day = row['pledged_per_backer'] * row['backers_per_day']

    # Note that we can't divide by zero:
    # return a large number if pledged_per_day is zero
    if pledged_per_day == 0:
        return 100000
    return amount_remaining / pledged_per_day

# Apply the function
df['days_to_goal'] = df.apply(days_to_goal, axis=1)

# %%
df
# Out:
#         goal  pledged  backers_count  country  staff_pick  spotlight  \
# 0        100        0              0        3           0          0
# 1       1400    14560            158        0           0          1
# 2     108400   142523           1425        4           0          0
# 3       4200     2477             24        0           0          0
# 4       7600     5265             53        0           0          0
# ...      ...      ...            ...      ...         ...        ...
# 1124   17130    15894            847        2           0          0
# 1125   97329    80937            862        6           0          0
# 1126   53597    40388             58        0           0          0
# 1127   71588    18102            274        0           0          0
# 1128   88382    28181            113        2           0          0
#
#       category  days_active  outcome  pledged_per_backer  backers_per_day  \
# 0            0           17        0            0.000000         0.000000
# 1            1           27        1           92.151899         5.851852
# 2            2           20        1          100.016140        71.250000
# 3            1           40        0          103.208333         0.600000
# 4            3            4        0           99.339623        13.250000
# ...        ...          ...      ...                 ...              ...
# 1124         5            6        0           18.765053       141.166667
# 1125         3           29        0           93.894432        29.724138
# 1126         9           46        0          696.344828         1.260870
# 1127         2           43        0           66.065693         6.372093
# 1128         2           41        0          249.389381         2.756098
#
#        days_to_goal
# 0     100000.000000
# 1          0.000000
# 2          0.000000
# 3         27.823981
# 4          1.773979
# ...             ...
# 1124       0.466591
# 1125       5.873309
# 1126      15.044419
# 1127     127.052149
# 1128      87.585288
#
# [1129 rows x 12 columns]
