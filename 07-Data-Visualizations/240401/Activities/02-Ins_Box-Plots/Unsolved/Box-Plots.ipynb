# %% [markdown]
# # Box Plots

# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def find_outliers_IQR(data, column):
    Q1 = data[column].quantile(0.25)
    Q2 = data[column].quantile(0.50)
    Q3 = data[column].quantile(0.75)

    IQR = Q3 - Q1
    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)

    outliers = data[column][(data[column] < lower_bound) | (data[column] > upper_bound)]

    return outliers

# %%
times = [96,98,100,105,85,88,95,100,101,102,97,98,5]
data  = pd.DataFrame(times, columns=['Reactions'])
data.plot(kind="box")
plt.show()

# %%
# Example outlier plot of reaction times
plt.boxplot(times)
plt.title("Reaction Times at Baseball Batting cage")
plt.ylabel("Reacion Time (ms)")
plt.show()

# %%
# We need to sort the data to determine which could be outliers
times.sort()
print(times)
# Out:
# [5, 85, 88, 95, 96, 97, 98, 98, 100, 100, 101, 102, 105]
